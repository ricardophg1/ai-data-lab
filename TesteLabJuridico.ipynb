# %% [markdown]
# <a href="https://colab.research.google.com/github/ricardophg1/ai-data-lab/blob/main/TesteLabJuridico.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <img src="https://media4.giphy.com/media/v1.Y2lkPTc5MGI3NjExZnJ0b2xua3ZsOGVqaXJlcnEwMWZ4c3h4N3hmeWk3ZjZzeDZvcDdkOSZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/7FrOU9tPbgAZtxV5mb/giphy.webp" align="right" width="1200px" height="500px" />

# %%
# Instalação das bibliotecas (-q tira a impressão do processo em tela)
# !pip install pandas numpy matplotlib seaborn pyspark requests beautifulsoup4 kafka-python flask plotly Faker -q

# %% [markdown]
# # Simulação de Dados de Processos Judiciais
#
# Este notebook tem como objetivo simular a geração e armazenamento de dados de processos judiciais fictícios. Ele utiliza bibliotecas de geração de dados aleatórios para criar registros que imitam informações reais de processos, facilitando testes e demonstrações em um ambiente de engenharia de dados.
#
# ## 1. Introdução
#
# A geração de dados sintéticos é uma prática comum para testar pipelines de dados, algoritmos e sistemas sem a necessidade de utilizar informações confidenciais ou sensíveis. Neste caso, estamos simulando processos judiciais com detalhes como partes envolvidas, status do processo, documentos anexos, entre outros.
#
# ## 2. Bibliotecas Utilizadas
#
# - **PySpark**: Utilizado para criar sessões Spark e manipular os dados em estruturas distribuídas.
# - **Faker**: Biblioteca que gera dados falsos realistas, como nomes, endereços e números de documentos.
# - **Outras bibliotecas**: `random`, `json`, `datetime`, `os`, e `glob` para auxiliar na geração e manipulação dos dados.
#
# ## 3. Processo de Geração de Dados
#
# ### 3.1. Configuração Inicial
#
# Iniciamos criando uma sessão do Spark e instanciando o Faker configurado para o idioma português do Brasil.
#
# ```python
# spark = SparkSession.builder.appName("ProcessoJudicial").getOrCreate()
# fake = Faker('pt_BR')
# ```
#
# ### 3.2. Função `generate_processo()`
#
# Esta função cria um dicionário representando um processo judicial com diversos campos, como:
#
# - **Informações básicas**: CPF/CNPJ, número único do processo, tribunal, status, etc.
# - **Partes envolvidas**: Detalhes sobre o autor e o réu, incluindo nome, nacionalidade, estado civil e endereço.
# - **Descrição da causa**: Fatos, fundamentos legais e pedidos.
# - **Andamento processual**: Lista de eventos ocorridos durante o processo.
# - **Documentos anexos**: Lista de documentos relacionados ao processo.
#
# A função utiliza o Faker e outras funções para preencher esses campos com dados aleatórios e realistas.
#
# ### 3.3. Função `ingest_data(num_processes=10000)`
#
# Esta função gera um número especificado de processos judiciais (por padrão, 10.000) e os converte em um DataFrame do Spark. Cada registro no DataFrame inclui:
#
# - **ID único**: Gerado com `uuid4()`.
# - **Dados do processo**: Armazenados como uma string JSON.
# - **Data de ingestão**: Timestamp do momento em que os dados foram gerados.
# - **Tempo de ingestão**: Um valor aleatório simulando o tempo gasto na ingestão.
# - **Detitime**: Outro timestamp do momento atual.
#
# ```python
# df, data = ingest_data()
# ```
#
# ## 4. Armazenamento dos Dados
#
# ### 4.1. Preparação dos Diretórios
#
# Os dados serão armazenados em dois formatos: JSON e Parquet. Diretórios específicos são criados para cada formato.
#
# ```python
# json_directory = '/content/data_lake/raw_data/json'
# parquet_directory = '/content/data_lake/raw_data/parquet'
# os.makedirs(json_directory, exist_ok=True)
# os.makedirs(parquet_directory, exist_ok=True)
# ```
#
# ### 4.2. Função `get_next_file_number()`
#
# Esta função auxilia na organização dos arquivos, determinando o próximo número sequencial para nomear os arquivos de saída, evitando sobreposição.
#
# ### 4.3. Salvando os Dados
#
# - **Formato Parquet**: Ideal para armazenamento e processamento em Big Data, devido à sua eficiência e compactação.
#
#   ```python
#   parquet_path = f'{parquet_directory}/processo_juridico_{next_file_number}.parquet'
#   df_raw.write.mode('overwrite').parquet(parquet_path)
#   ```
#
# - **Formato JSON**: Fácil de ler e ideal para interoperabilidade entre sistemas.
#
#   ```python
#   json_path = f'{json_directory}/processo_juridico_{next_file_number}.json'
#   with open(json_path, 'w') as json_file:
#       json.dump(raw_data, json_file)
#   ```
#
# ## 5. Visualização dos Dados
#
# Para verificar se os dados foram gerados corretamente, exibimos uma amostra dos registros e algumas informações adicionais.
#
# ```python
# print("\nAmostra dos dados gerados:")
# df_raw.show(5, truncate=False)
#
# print(f"\nTotal de registros gerados: {df_raw.count()}")
# print(f"Schema do DataFrame:")
# df_raw.printSchema()
# ```
#
# ## 6. Conclusão
#
# Este notebook demonstra como gerar e armazenar dados sintéticos de processos judiciais, úteis para testes e desenvolvimento em projetos de engenharia de dados. Ao simular dados realistas, é possível desenvolver e validar pipelines de dados sem expor informações sensíveis.
#
# ## 7. Observações
#
# - **Segurança dos Dados**: Todos os dados gerados são fictícios e não correspondem a informações reais.
# - **Escalabilidade**: O número de processos gerados pode ser ajustado conforme a necessidade, permitindo simulações em diferentes escalas.
# - **Flexibilidade**: A estrutura dos dados pode ser adaptada para incluir ou remover campos, conforme os requisitos do projeto.
#
# ---
#
# **Nota**: Este notebook foi desenvolvido para fins educacionais e de teste, auxiliando na compreensão de processos de geração e manipulação de dados em um contexto de engenharia de dados.

# %% [markdown]
# ![bradesco-teste.drawio.svg](data:image/svg+xml;base64,...)

# %%
from pyspark.sql import SparkSession
from pyspark.sql.types import *
from pyspark.sql import functions as F
from pyspark.sql.functions import udf, from_json, col, explode
from faker import Faker
from pyspark.sql.types import StringType, StructType, StructField, ArrayType, DoubleType
from cryptography.fernet import Fernet
from datetime import datetime
import random
import json
import os
import glob

# %%
spark = SparkSession.builder.appName("ProcessoJudicial").getOrCreate()
fake = Faker('pt_BR')

def generate_processo():
    tribunais = ['TJ-SC', 'TJ-SP', 'TJ-RJ', 'TRF-1', 'TRF-2', 'TRF-3', 'TRF-4', 'TRF-5', 'TST', 'STJ', 'STF']
    status = ['BAIXADO', 'EM ANDAMENTO', 'SUSPENSO', 'ARQUIVADO', 'JULGADO', 'EM RECURSO']
    areas = ['JUIZADO ESPECIAL CÍVEL', 'VARA CÍVEL', 'VARA CRIMINAL', 'VARA TRABALHISTA', 'VARA FEDERAL', 'VARA DE FAMÍLIA']
    segmentos = ['JUSTIÇA ESTADUAL', 'JUSTIÇA FEDERAL', 'JUSTIÇA DO TRABALHO']
    ufs = ['SC', 'SP', 'RJ', 'MG', 'RS', 'PR', 'BA', 'DF']
    estado_civil = ['Solteiro(a)', 'Casado(a)', 'Divorciado(a)', 'Viúvo(a)']

    return {
        "cpfCnpj": fake.cpf(),
        "urlProcesso": f"https://eproc{random.randint(1,5)}.tjsc.jus.br/eproc",
        "numeroProcessoUnico": f"{random.randint(0, 9999999):07d}-{random.randint(0, 99):02d}.{random.randint(2000, 2023)}.{random.randint(1, 9)}.{random.randint(0, 99):02d}.{random.randint(0, 9999):04d}",
        "statusObservacao": random.choice(status),
        "grauProcesso": str(random.randint(1, 3)),
        "juiz": fake.name(),
        "area": f"{random.choice(areas)} - {fake.city().upper()}",
        "segmento": random.choice(segmentos),
        "tribunal": random.choice(tribunais),
        "uf": random.choice(ufs),
        "valor_causa": round(random.uniform(1000, 1000000), 2),
        "data_distribuicao": fake.date_between(start_date='-5y', end_date='today').isoformat(),
        "partes": {
            "autor": {
                "nome": fake.name(),
                "nacionalidade": "Brasileira",
                "estado_civil": random.choice(estado_civil),
                "profissao": fake.job(),
                "cpf": fake.cpf(),
                "endereco": fake.address()
            },
            "reu": {
                "nome": fake.company() if random.choice([True, False]) else fake.name(),
                "nacionalidade": "Brasileira",
                "estado_civil": random.choice(estado_civil),
                "profissao": fake.job(),
                "cpf_cnpj": fake.cpf() if random.choice([True, False]) else fake.cnpj(),
                "endereco": fake.address()
            }
        },
        "descricao_causa": {
            "fatos": fake.text(max_nb_chars=500),
            "fundamento_legal": f"Art. {random.randint(1, 1000)} do Código {random.choice(['Civil', 'Penal', 'de Processo Civil', 'de Processo Penal', 'Trabalhista'])}",
            "pedido": fake.text(max_nb_chars=200)
        },
        "andamento_processual": [
            {
                "data": fake.date_between(start_date='-5y', end_date='today').isoformat(),
                "descricao": random.choice(['Petição inicial protocolada', 'Citação realizada', 'Contestação apresentada', 'Audiência designada', 'Sentença proferida', 'Recurso interposto'])
            } for _ in range(random.randint(3, 10))
        ],
        "documentos_anexos": [
            f"{random.choice(['Petição', 'Procuração', 'Comprovante', 'Laudo', 'Certidão'])} - {fake.file_name(extension='pdf')}"
            for _ in range(random.randint(2, 5))
        ]
    }

def ingest_data(num_processes=10000):
    data = [generate_processo() for _ in range(num_processes)]
    df = spark.createDataFrame([(
        str(fake.uuid4()),
        json.dumps(processo),
        datetime.now(),
        random.uniform(0.1, 1.0),
        datetime.now()
    ) for processo in data],
    ["id", "data_source", "data", "tempo_da_ingestao", "detitime"])

    return df, data

def get_next_file_number(directory, prefix):
    existing_files = glob.glob(f"{directory}/{prefix}_*.json")
    if not existing_files:
        return 1
    numbers = [int(f.split('_')[-1].split('.')[0]) for f in existing_files]
    return max(numbers) + 1

# Criar diretórios para armazenamento
json_directory = '/content/data_lake/raw_data/json'
parquet_directory = '/content/data_lake/raw_data/parquet'
os.makedirs(json_directory, exist_ok=True)
os.makedirs(parquet_directory, exist_ok=True)

# Gerar e ingerir dados
df_raw, raw_data = ingest_data()

# Obter o próximo número de arquivo
next_file_number = get_next_file_number(json_directory, 'processo_juridico')

# Salvar dados brutos em formato Parquet
parquet_path = f'{parquet_directory}/processo_juridico_{next_file_number}.parquet'
df_raw.write.mode('overwrite').parquet(parquet_path)
print(f"Dados brutos salvos em formato Parquet: {parquet_path}")

# Salvar dados brutos em formato JSON
json_path = f'{json_directory}/processo_juridico_{next_file_number}.json'
with open(json_path, 'w') as json_file:
    json.dump(raw_data, json_file)
print(f"Dados brutos salvos em formato JSON: {json_path}")

# Exibir alguns registros para verificação
print("\nAmostra dos dados gerados:")
df_raw.show(5, truncate=False)

# Informações adicionais
print(f"\nTotal de registros gerados: {df_raw.count()}")
print(f"Schema do DataFrame:")
df_raw.printSchema()
# Out:
# Dados brutos salvos em formato Parquet: /content/data_lake/raw_data/parquet/processo_juridico_2.parquet
# Dados brutos salvos em formato JSON: /content/data_lake/raw_data/json/processo_juridico_2.json
#
# Amostra dos dados gerados:
# +------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------+-------------------+--------------------------+
# |id                                  |data_source                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   |data                      |tempo_da_ingestao  |detitime                  |
# +------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------+-------------------+--------------------------+
# |a1a967c5-f1e1-44a7-b060-f476d16da560|{"cpfCnpj": "019.543.627-06", "urlProcesso": "https://eproc4.tjsc.jus.br/eproc", "numeroProcessoUnico": "0515611-81.2019.9.57.4762", "statusObservacao": "JULGADO", "grauProcesso": "1", "juiz": "Allana Silva", "area": "VARA FEDERAL - OLIVEIRA GRANDE", "segmento": "JUSTI\u00c7A DO TRABALHO", "tribunal": "TJ-RJ", "uf": "MG", "valor_causa": 419030.54, "data_distribuicao": "2020-10-31", "partes": {"autor": {"nome": "Vin\u00edcius C\u00e2mara", "nacionalidade": "Brasileira", "estado_civil": "Vi\u00favo(a)", "profissao": "Oftalmologista", "cpf": "068.954.237-29", "endereco": "Lago Montenegro, 501\nVila Sat\u00e9lite\n14274-843 Fernandes / PA"}, "reu": {"nome": "Isabelly Almeida", "nacionalidade": "Brasileira", "estado_civil": "Divorciado(a)", "profissao": "Engenheiro t\u00eaxtil", "cpf_cnpj": "795.304.286-00", "endereco": "Rua de Viana, 6\nDiamante\n37581768 Freitas do Campo / CE"}}, "descricao_causa": {"fatos": "Alias ex aspernatur mollitia quia amet deleniti mollitia. Nobis occaecati aut officia error dolores. Impedit molestiae nesciunt possimus porro.\nIure impedit facilis ut. Possimus et expedita similique cupiditate nulla quas aperiam. Nulla eum culpa illo.\nSoluta maiores ex. Autem perferendis mollitia.\nDoloribus pariatur dicta ipsum. Ad molestiae optio non illum ipsa corporis voluptates.\nSaepe et soluta id qui. Incidunt id assumenda quae. Cum sint eligendi libero commodi non deleniti.", "fundamento_legal": "Art. 712 do C\u00f3digo de Processo Penal", "pedido": "A possimus perferendis minima beatae animi expedita quaerat.\nExcepturi eveniet a quidem delectus odit. Amet laborum quas magni. Labore ex sapiente dolorum nihil libero."}, "andamento_processual": [{"data": "2019-12-25", "descricao": "Contesta\u00e7\u00e3o apresentada"}, {"data": "2021-11-13", "descricao": "Peti\u00e7\u00e3o inicial protocolada"}, {"data": "2021-03-30", "descricao": "Contesta\u00e7\u00e3o apresentada"}], "documentos_anexos": ["Laudo - error.pdf", "Peti\u00e7\u00e3o - aspernatur.pdf", "Comprovante - magnam.pdf"]}                                                                                                                                                                                                                                                                                                                                                                                                        |2024-09-22 13:49:40.14298 |0.32380294434416124|2024-09-22 13:49:40.142983|
# |6cb98827-6a96-46ef-98af-cddd6cb22da4|{"cpfCnpj": "853.104.629-70", "urlProcesso": "https://eproc4.tjsc.jus.br/eproc", "numeroProcessoUnico": "0548641-09.2006.9.25.4765", "statusObservacao": "ARQUIVADO", "grauProcesso": "1", "juiz": "Emanuelly Silveira", "area": "VARA TRABALHISTA - CAVALCANTE DO GALHO", "segmento": "JUSTI\u00c7A FEDERAL", "tribunal": "TRF-2", "uf": "BA", "valor_causa": 63028.97, "data_distribuicao": "2021-11-20", "partes": {"autor": {"nome": "Dra. Ana Sophia Jesus", "nacionalidade": "Brasileira", "estado_civil": "Casado(a)", "profissao": "Tecn\u00f3logo em neg\u00f3cios imobili\u00e1rios", "cpf": "251.849.376-09", "endereco": "Fazenda Alexandre Novaes, 60\nS\u00e3o Benedito\n46826324 Ara\u00fajo de Pastor / BA"}, "reu": {"nome": "Pimenta Ramos - ME", "nacionalidade": "Brasileira", "estado_civil": "Divorciado(a)", "profissao": "Telegrafista", "cpf_cnpj": "63.852.401/0001-90", "endereco": "Quadra Monteiro, 54\nJardim Am\u00e9rica\n79775-273 Cavalcanti / PA"}}, "descricao_causa": {"fatos": "Sint blanditiis beatae quam consequatur quis. Provident sed rem fuga ipsam totam vel.\nMaiores adipisci quidem nihil debitis sequi quibusdam. Modi maiores eum inventore.\nTenetur ipsam ullam laudantium. Totam tempora ab.\nNulla magni eaque aliquam modi iste. Harum eligendi perferendis tempora.\nSapiente dicta at asperiores ab cum dignissimos vitae. Cumque natus voluptatum ducimus. Ducimus sunt ad doloribus quisquam qui voluptas.", "fundamento_legal": "Art. 564 do C\u00f3digo Trabalhista", "pedido": "Eius dolores tenetur amet aspernatur. Nobis aliquam aspernatur corrupti.\nAssumenda pariatur et sed quaerat voluptatum vel. Ullam quam aliquam similique. A dolores quisquam aspernatur quia deleniti."}, "andamento_processual": [{"data": "2024-02-11", "descricao": "Recurso interposto"}, {"data": "2020-06-20", "descricao": "Audi\u00eancia designada"}, {"data": "2022-03-25", "descricao": "Recurso interposto"}, {"data": "2022-09-19", "descricao": "Contesta\u00e7\u00e3o apresentada"}, {"data": "2021-10-05", "descricao": "Audi\u00eancia designada"}, {"data": "2021-11-22", "descricao": "Recurso interposto"}, {"data": "2022-03-22", "descricao": "Audi\u00eancia designada"}, {"data": "2022-03-03", "descricao": "Cita\u00e7\u00e3o realizada"}, {"data": "2021-03-27", "descricao": "Cita\u00e7\u00e3o realizada"}], "documentos_anexos": ["Certid\u00e3o - provident.pdf", "Comprovante - soluta.pdf", "Procura\u00e7\u00e3o - nam.pdf"]}|2024-09-22 13:49:40.143045|0.8200689964667652 |2024-09-22 13:49:40.143047|
# |fce1fd2e-c248-4669-88ac-00bc468dfa94|{"cpfCnpj": "085.439.162-24", "urlProcesso": "https://eproc2.tjsc.jus.br/eproc", "numeroProcessoUnico": "1309183-32.2011.8.75.8958", "statusObservacao": "EM RECURSO", "grauProcesso": "2", "juiz": "Ana L\u00edvia Porto", "area": "VARA TRABALHISTA - RIBEIRO", "segmento": "JUSTI\u00c7A DO TRABALHO", "tribunal": "STJ", "uf": "SP", "valor_causa": 930205.51, "data_distribuicao": "2022-02-20", "partes": {"autor": {"nome": "Sra. Ana J\u00falia Albuquerque", "nacionalidade": "Brasileira", "estado_civil": "Vi\u00favo(a)", "profissao": "Agr\u00f4nomo", "cpf": "802.634.571-17", "endereco": "Trevo Moraes, 40\nGrotinha\n86314-680 Montenegro dos Dourados / DF"}, "reu": {"nome": "Caroline Rezende", "nacionalidade": "Brasileira", "estado_civil": "Divorciado(a)", "profissao": "Numer\u00f3logo", "cpf_cnpj": "62.891.345/0001-30", "endereco": "Recanto Moraes, 66\nJardim Atl\u00e2ntico\n53226110 Alves Verde / PR"}}, "descricao_causa": {"fatos": "Culpa totam odio vitae. Explicabo sed eveniet. Distinctio ut explicabo at explicabo necessitatibus impedit doloremque.\nReiciendis quia nesciunt molestias quis incidunt labore architecto. Ut repellat facilis assumenda nostrum eos.\nVoluptatem nisi dolores accusantium perferendis. Occaecati ipsa consectetur fugiat assumenda reiciendis quisquam. Deleniti soluta quaerat quos ea.\nMolestias ipsam vitae quidem mollitia. Laboriosam quisquam doloribus doloribus incidunt assumenda.", "fundamento_legal": "Art. 912 do C\u00f3digo Civil", "pedido": "Sit atque laudantium ea rem animi sunt nisi. Esse sint aspernatur odit nostrum illo voluptates. Maxime eum eum nesciunt consequatur perferendis. Pariatur nam ut illum vitae architecto."}, "andamento_processual": [{"data": "2022-09-17", "descricao": "Cita\u00e7\u00e3o realizada"}, {"data": "2022-04-30", "descricao": "Contesta\u00e7\u00e3o apresentada"}, {"data": "2021-12-23", "descricao": "Audi\u00eancia designada"}, {"data": "2022-01-13", "descricao": "Recurso interposto"}, {"data": "2020-08-04", "descricao": "Audi\u00eancia designada"}], "documentos_anexos": ["Procura\u00e7\u00e3o - iste.pdf", "Laudo - eligendi.pdf", "Laudo - enim.pdf", "Peti\u00e7\u00e3o - labore.pdf", "Peti\u00e7\u00e3o - praesentium.pdf"]}                                                                                                                                                                                                                    |2024-09-22 13:49:40.143096|0.25743344592844786|2024-09-22 13:49:40.143097|
# |7e4480fc-57cc-404c-8f73-ce5c06b51a43|{"cpfCnpj": "172.358.046-53", "urlProcesso": "https://eproc3.tjsc.jus.br/eproc", "numeroProcessoUnico": "9319040-36.2021.1.52.3368", "statusObservacao": "EM RECURSO", "grauProcesso": "1", "juiz": "Dr. Heitor Ribeiro", "area": "VARA DE FAM\u00cdLIA - MACEDO DA PRAIA", "segmento": "JUSTI\u00c7A ESTADUAL", "tribunal": "STF", "uf": "SC", "valor_causa": 961021.83, "data_distribuicao": "2020-11-09", "partes": {"autor": {"nome": "Ot\u00e1vio Albuquerque", "nacionalidade": "Brasileira", "estado_civil": "Divorciado(a)", "profissao": "Seringueiro", "cpf": "517.309.426-52", "endereco": "Loteamento Lu\u00edsa Sousa, 708\nBaleia\n46355-861 Rios do Campo / RS"}, "reu": {"nome": "Ara\u00fajo", "nacionalidade": "Brasileira", "estado_civil": "Divorciado(a)", "profissao": "Psic\u00f3logo", "cpf_cnpj": "970.234.518-97", "endereco": "N\u00facleo de Costela, 81\nBoa Viagem\n80173684 Moreira de da Cunha / PA"}}, "descricao_causa": {"fatos": "Quod beatae dolores placeat magni voluptatum. Assumenda non repudiandae dolores explicabo tempore. Occaecati quam deserunt mollitia dolores. Quas delectus dolore.\nQuasi autem voluptatum voluptates dolorem deleniti beatae. Delectus praesentium eum in ab optio.\nQuos debitis voluptatum harum facere accusamus.\nRecusandae saepe illum. Magnam libero iusto vitae. Optio esse eveniet fuga nobis.\nVitae facere occaecati molestiae vel labore alias. Veniam quisquam vel ipsam nesciunt fugiat.", "fundamento_legal": "Art. 809 do C\u00f3digo de Processo Civil", "pedido": "Ipsa aliquam cumque assumenda repellendus. Tempore voluptatum tempore inventore iure tenetur et. Pariatur at ullam sunt accusantium facilis culpa."}, "andamento_processual": [{"data": "2021-12-30", "descricao": "Recurso interposto"}, {"data": "2023-05-24", "descricao": "Cita\u00e7\u00e3o realizada"}, {"data": "2023-09-29", "descricao": "Senten\u00e7a proferida"}], "documentos_anexos": ["Comprovante - mollitia.pdf", "Certid\u00e3o - ipsa.pdf", "Procura\u00e7\u00e3o - neque.pdf", "Laudo - consequuntur.pdf"]}                                                                                                                                                                                                                                                                                                                                                                                                                   |2024-09-22 13:49:40.143137|0.1360850004066764 |2024-09-22 13:49:40.143138|
# |9fc26e4e-40fd-42bd-a0ac-ae8f5a963b60|{"cpfCnpj": "507.261.348-80", "urlProcesso": "https://eproc1.tjsc.jus.br/eproc", "numeroProcessoUnico": "5018992-35.2003.8.74.3726", "statusObservacao": "EM ANDAMENTO", "grauProcesso": "3", "juiz": "Valentina Nascimento", "area": "VARA TRABALHISTA - PORTO DO NORTE", "segmento": "JUSTI\u00c7A ESTADUAL", "tribunal": "STJ", "uf": "DF", "valor_causa": 964885.84, "data_distribuicao": "2020-12-05", "partes": {"autor": {"nome": "Diego Cavalcanti", "nacionalidade": "Brasileira", "estado_civil": "Divorciado(a)", "profissao": "Juiz de direito", "cpf": "904.721.356-43", "endereco": "Rua de Caldeira, 101\nVila Trinta E Um De Mar\u00e7o\n05773-038 Fonseca do Norte / PR"}, "reu": {"nome": "Cavalcante", "nacionalidade": "Brasileira", "estado_civil": "Vi\u00favo(a)", "profissao": "Armador", "cpf_cnpj": "83.214.906/0001-36", "endereco": "Feira Aparecida, 928\nVila Santo Ant\u00f4nio Barroquinha\n38045-536 Viana do Galho / RS"}}, "descricao_causa": {"fatos": "Earum blanditiis suscipit dignissimos animi incidunt labore. Veritatis nam minima sunt voluptatem aut fugit. Nam aut odit iusto voluptas. Eum ab est cum praesentium repudiandae quisquam.\nDolore ea saepe inventore doloribus voluptatibus facilis. Ad excepturi odit dolorum laudantium eius voluptate. Laboriosam explicabo itaque. Cumque fugit illo veritatis tempora.\nDelectus ullam ducimus asperiores repellendus error atque. Nihil aut fugit occaecati quod.", "fundamento_legal": "Art. 675 do C\u00f3digo Civil", "pedido": "Ullam voluptatum omnis quisquam unde dolores vero. Iste consectetur repudiandae blanditiis voluptates. Aspernatur eveniet possimus quos."}, "andamento_processual": [{"data": "2021-03-09", "descricao": "Cita\u00e7\u00e3o realizada"}, {"data": "2022-05-04", "descricao": "Recurso interposto"}, {"data": "2024-04-20", "descricao": "Cita\u00e7\u00e3o realizada"}, {"data": "2021-07-04", "descricao": "Cita\u00e7\u00e3o realizada"}, {"data": "2020-02-01", "descricao": "Audi\u00eancia designada"}, {"data": "2021-05-04", "descricao": "Recurso interposto"}, {"data": "2022-03-11", "descricao": "Peti\u00e7\u00e3o inicial protocolada"}, {"data": "2024-07-16", "descricao": "Senten\u00e7a proferida"}], "documentos_anexos": ["Certid\u00e3o - natus.pdf", "Laudo - aspernatur.pdf", "Laudo - voluptas.pdf", "Comprovante - explicabo.pdf"]}                                                                                                            |2024-09-22 13:49:40.143181|0.9380032154717507 |2024-09-22 13:49:40.143182|
# +------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------+-------------------+--------------------------+
# only showing top 5 rows
#
#
# Total de registros gerados: 10000
# Schema do DataFrame:
# root
#  |-- id: string (nullable = true)
#  |-- data_source: string (nullable = true)
#  |-- data: timestamp (nullable = true)
#  |-- tempo_da_ingestao: double (nullable = true)
#  |-- detitime: timestamp (nullable = true)

# %% [markdown]
# # Processamento e Criptografia de Dados de Processos Judiciais
#
# Dando continuidade ao projeto de simulação de dados de processos judiciais, este notebook se concentra no processamento dos dados brutos gerados anteriormente, aplicando criptografia em campos sensíveis e armazenando os dados processados de forma segura.
#
# ## 1. Introdução
#
# Após a geração e armazenamento dos dados brutos dos processos judiciais, é necessário processar esses dados para extrair informações relevantes, proteger dados confidenciais e prepará-los para análises futuras. Este notebook realiza essas tarefas, enfatizando a importância da segurança e integridade dos dados.
#
# ## 2. Bibliotecas Utilizadas
#
# - **PySpark**: Para processamento distribuído e manipulação de grandes volumes de dados.
# - **Fernet (Cryptography)**: Utilizada para criptografar campos sensíveis, garantindo a segurança dos dados pessoais.
# - **Outras bibliotecas**: `os`, `glob`, e `datetime` auxiliam na manipulação de arquivos e diretórios.
#
# ## 3. Processo de Processamento de Dados
#
# ### 3.1. Iniciando a Sessão do Spark
#
# Primeiramente, iniciamos uma nova sessão do Spark para realizar o processamento dos dados.
#
# ```python
# spark = SparkSession.builder.appName("ProcessoJudicial").getOrCreate()
# print("Spark Session iniciada com sucesso.")
# ```
#
# ### 3.2. Configuração da Criptografia
#
# Para proteger os dados pessoais, configuramos um mecanismo de criptografia usando a biblioteca `Fernet`.
#
# ```python
# encryption_key = Fernet.generate_key()
# cipher_suite = Fernet(encryption_key)
# ```
#
# - **Chave de Criptografia**: Uma chave única é gerada para criptografar e descriptografar os dados.
# - **Cipher Suite**: Utilizada para aplicar a criptografia nos campos desejados.
#
# ### 3.3. Função de Criptografia
#
# Criamos uma função personalizada (UDF) para criptografar os campos sensíveis no DataFrame do Spark.
#
# ```python
# @udf(returnType=StringType())
# def encrypt_udf(data):
#     if data is None:
#         return "DADO_NAO_DISPONIVEL"
#     return cipher_suite.encrypt(str(data).encode()).decode()
# ```
#
# - **Tratamento de Nulos**: Se o dado for `None`, retorna uma mensagem indicando que o dado não está disponível.
# - **Criptografia**: Aplica a criptografia no dado e o retorna como uma string.
#
# ### 3.4. Função `process_data()`
#
# Esta função é responsável por processar o DataFrame contendo os dados brutos.
#
# #### Passo a Passo do Processamento:
#
# 1. **Contagem de Registros**: Informa quantos registros serão processados.
#    ```python
#    print(f"Iniciando processamento de {df.count()} registros.")
#    ```
#
# 2. **Definição do Esquema JSON**: Define a estrutura dos dados para interpretar corretamente o JSON armazenado na coluna `data_source`.
#    ```python
#    json_schema = StructType([
#        # Estrutura detalhada conforme os campos dos processos judiciais
#    ])
#    ```
#
# 3. **Expansão do JSON**: Converte a string JSON em colunas estruturadas.
#    ```python
#    df_expanded = df.withColumn("data_parsed", from_json(col("data_source"), json_schema))
#    print("JSON expandido com sucesso.")
#    ```
#
# 4. **Extração de Campos Relevantes**: Seleciona os campos importantes para análise.
#    ```python
#    fields_to_extract = [
#        "cpfCnpj", "urlProcesso", "numeroProcessoUnico", # e outros campos...
#    ]
#    for field in fields_to_extract:
#        df_expanded = df_expanded.withColumn(field.replace(".", "_"), col(f"data_parsed.{field}"))
#    print("Campos relevantes extraídos.")
#    ```
#
# 5. **Tratamento de Campos Complexos**: Lida com campos que são arrays ou estruturas aninhadas.
#    ```python
#    df_expanded = df_expanded.withColumn("andamento_processual", col("data_parsed.andamento_processual"))
#    df_expanded = df_expanded.withColumn("documentos_anexos", col("data_parsed.documentos_anexos"))
#    ```
#
# 6. **Criptografia de Campos Sensíveis**: Aplica a função de criptografia nos campos que contêm informações pessoais.
#    ```python
#    sensitive_fields = ["cpfCnpj", "partes_autor_cpf", "partes_reu_cpf_cnpj", # e outros campos...
#    ]
#    for field in sensitive_fields:
#        df_expanded = df_expanded.withColumn(f"{field}_encrypted", encrypt_udf(col(field)))
#    print("Campos sensíveis criptografados.")
#    ```
#
# 7. **Seleção das Colunas Finais**: Define quais colunas serão mantidas no DataFrame final.
#    ```python
#    final_columns = ["id", "data", "detitime", "tempo_da_ingestao"] + \
#                    [f.replace(".", "_") for f in fields_to_extract] + \
#                    [f"{f}_encrypted" for f in sensitive_fields] + \
#                    ["andamento_processual", "documentos_anexos"]
#    df_final = df_expanded.select(final_columns)
#    print(f"Processamento concluído. Total de colunas: {len(df_final.columns)}")
#    ```
#
# ### 3.5. Processamento dos Arquivos de Dados Brutos
#
# Localizamos e processamos todos os arquivos Parquet contendo os dados brutos.
#
# ```python
# raw_data_dir = '/content/data_lake/raw_data/parquet'
# parquet_files = glob.glob(os.path.join(raw_data_dir, '**', '*.parquet'), recursive=True)
# ```
#
# - **Verificação de Arquivos**: Certifica-se de que existem arquivos para processar.
# - **Loop de Processamento**: Para cada arquivo encontrado, realiza o processamento e salva os dados processados.
#
# ### 3.6. Salvando os Dados Processados
#
# Os dados processados são armazenados em um novo diretório, separados dos dados brutos.
#
# ```python
# processed_data_path = f'/content/data_lake/processed_data/{os.path.basename(file_path)}'
# os.makedirs(os.path.dirname(processed_data_path), exist_ok=True)
# df_processed.write.mode('overwrite').parquet(processed_data_path)
# print(f"Dados processados salvos em {processed_data_path}")
# ```
#
# ### 3.7. Visualização dos Dados Processados
#
# Para verificar o resultado do processamento, exibimos uma amostra dos dados e o esquema do DataFrame.
#
# ```python
# print("\nAmostra dos dados processados:")
# df_processed.show(5, truncate=False)
# print("\nSchema dos dados processados:")
# df_processed.printSchema()
# ```
#
# ### 3.8. Encerrando a Sessão do Spark
#
# Após o processamento, fechamos a sessão do Spark.
#
# ```python
# spark.stop()
# print("Sessão do Spark encerrada.")
# ```
#
# ## 4. Conclusão
#
# Este notebook complementa o processo de geração de dados de processos judiciais, adicionando uma camada crucial de processamento e segurança. Ao extrair informações relevantes e criptografar dados sensíveis, garantimos a conformidade com práticas recomendadas de proteção de dados e preparamos os dados para análises futuras.
#
# ## 5. Observações
#
# - **Segurança da Informação**: A criptografia dos dados pessoais é essencial para proteger a privacidade e cumprir com regulamentações, como a LGPD (Lei Geral de Proteção de Dados).
# - **Flexibilidade do Pipeline**: O processo pode ser adaptado para incluir novos campos ou alterar as regras de processamento conforme necessário.
# - **Reusabilidade**: As funções definidas podem ser reutilizadas em outros projetos que demandem processamento similar.
#
# ---
#
# **Nota**: Este notebook foi desenvolvido para fins educacionais e de teste, ilustrando como processar e proteger dados em um contexto de engenharia de dados.

# %%
# Iniciar a sessão do Spark
spark = SparkSession.builder.appName("ProcessoJudicial").getOrCreate()
print("Spark Session iniciada com sucesso.")

# Configurar criptografia
encryption_key = Fernet.generate_key()
cipher_suite = Fernet(encryption_key)

@udf(returnType=StringType())
def encrypt_udf(data):
    if data is None:
        return "DADO_NAO_DISPONIVEL"
    return cipher_suite.encrypt(str(data).encode()).decode()

def process_data(df):
    print(f"Iniciando processamento de {df.count()} registros.")

    # Definir o schema completo para o JSON
    json_schema = StructType([
        StructField("cpfCnpj", StringType()),
        StructField("urlProcesso", StringType()),
        StructField("numeroProcessoUnico", StringType()),
        StructField("statusObservacao", StringType()),
        StructField("grauProcesso", StringType()),
        StructField("juiz", StringType()),
        StructField("area", StringType()),
        StructField("segmento", StringType()),
        StructField("tribunal", StringType()),
        StructField("uf", StringType()),
        StructField("valor_causa", DoubleType()),
        StructField("data_distribuicao", StringType()),
        StructField("partes", StructType([
            StructField("autor", StructType([
                StructField("nome", StringType()),
                StructField("nacionalidade", StringType()),
                StructField("estado_civil", StringType()),
                StructField("profissao", StringType()),
                StructField("cpf", StringType()),
                StructField("endereco", StringType())
            ])),
            StructField("reu", StructType([
                StructField("nome", StringType()),
                StructField("nacionalidade", StringType()),
                StructField("estado_civil", StringType()),
                StructField("profissao", StringType()),
                StructField("cpf_cnpj", StringType()),
                StructField("endereco", StringType())
            ]))
        ])),
        StructField("descricao_causa", StructType([
            StructField("fatos", StringType()),
            StructField("fundamento_legal", StringType()),
            StructField("pedido", StringType())
        ])),
        StructField("andamento_processual", ArrayType(StructType([
            StructField("data", StringType()),
            StructField("descricao", StringType())
        ]))),
        StructField("documentos_anexos", ArrayType(StringType()))
    ])

    # Expandir o JSON da coluna data_source
    df_expanded = df.withColumn("data_parsed", from_json(col("data_source"), json_schema))
    print("JSON expandido com sucesso.")

    # Extrair todos os campos relevantes
    fields_to_extract = [
        "cpfCnpj", "urlProcesso", "numeroProcessoUnico", "statusObservacao", "grauProcesso",
        "juiz", "area", "segmento", "tribunal", "uf", "valor_causa", "data_distribuicao",
        "partes.autor.nome", "partes.autor.nacionalidade", "partes.autor.estado_civil",
        "partes.autor.profissao", "partes.autor.cpf", "partes.autor.endereco",
        "partes.reu.nome", "partes.reu.nacionalidade", "partes.reu.estado_civil",
        "partes.reu.profissao", "partes.reu.cpf_cnpj", "partes.reu.endereco",
        "descricao_causa.fatos", "descricao_causa.fundamento_legal", "descricao_causa.pedido"
    ]

    for field in fields_to_extract:
        df_expanded = df_expanded.withColumn(field.replace(".", "_"), col(f"data_parsed.{field}"))

    # Tratar campos de array
    df_expanded = df_expanded.withColumn("andamento_processual", col("data_parsed.andamento_processual"))
    df_expanded = df_expanded.withColumn("documentos_anexos", col("data_parsed.documentos_anexos"))

    print("Campos relevantes extraídos.")

    # Criptografar campos sensíveis
    sensitive_fields = ["cpfCnpj", "partes_autor_cpf", "partes_reu_cpf_cnpj",
                        "partes_autor_nome", "partes_reu_nome",
                        "partes_autor_endereco", "partes_reu_endereco"]
    for field in sensitive_fields:
        df_expanded = df_expanded.withColumn(f"{field}_encrypted", encrypt_udf(col(field)))
    print("Campos sensíveis criptografados.")

    # Selecionar colunas finais
    final_columns = ["id", "data", "detitime", "tempo_da_ingestao"] + \
                    [f.replace(".", "_") for f in fields_to_extract] + \
                    [f"{f}_encrypted" for f in sensitive_fields] + \
                    ["andamento_processual", "documentos_anexos"]
    df_final = df_expanded.select(final_columns)

    print(f"Processamento concluído. Total de colunas: {len(df_final.columns)}")
    return df_final

# Diretório dos dados brutos
raw_data_dir = '/content/data_lake/raw_data/parquet'

# Obter lista de todos os arquivos Parquet no diretório raw_data
parquet_files = glob.glob(os.path.join(raw_data_dir, '**', '*.parquet'), recursive=True)

if not parquet_files:
    print(f"Nenhum arquivo Parquet encontrado em {raw_data_dir}")
    exit()

# Processar cada arquivo Parquet
for file_path in parquet_files:
    print(f"Processando arquivo: {file_path}")
    df_raw = spark.read.parquet(file_path)
    df_processed = process_data(df_raw)

    # Salvar dados processados
    processed_data_path = f'/content/data_lake/processed_data/{os.path.basename(file_path)}'
    os.makedirs(os.path.dirname(processed_data_path), exist_ok=True)
    df_processed.write.mode('overwrite').parquet(processed_data_path)
    print(f"Dados processados salvos em {processed_data_path}")

    # Exibir amostra e schema dos dados processados
    print("\nAmostra dos dados processados:")
    df_processed.show(5, truncate=False)
    print("\nSchema dos dados processados:")
    df_processed.printSchema()

    print(f"\nTotal de registros processados: {df_processed.count()}")
    print(f"Total de colunas: {len(df_processed.columns)}")

# Fechar a sessão do Spark
spark.stop()
print("Sessão do Spark encerrada.")
# Out:
# Spark Session iniciada com sucesso.
# Processando arquivo: /content/data_lake/raw_data/parquet/processo_juridico_1.parquet
# Iniciando processamento de 10000 registros.
# JSON expandido com sucesso.
# Campos relevantes extraídos.
# Campos sensíveis criptografados.
# Processamento concluído. Total de colunas: 40
# Dados processados salvos em /content/data_lake/processed_data/processo_juridico_1.parquet
#
# Amostra dos dados processados:
# +------------------------------------+--------------------------+--------------------------+-------------------+--------------+--------------------------------+-------------------------+----------------+------------+-----------------------+--------------------------------+-------------------+--------+---+-----------+-----------------+-----------------+--------------------------+-------------------------+-------------------------+----------------+--------------------------------------------------------------------------+---------------------+------------------------+-----------------------+---------------------+-------------------+-----------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------+
# |id                                  |data                      |detitime                  |tempo_da_ingestao  |cpfCnpj       |urlProcesso                     |numeroProcessoUnico      |statusObservacao|grauProcesso|juiz                   |area                            |segmento           |tribunal|uf |valor_causa|data_distribuicao|partes_autor_nome|partes_autor_nacionalidade|partes_autor_estado_civil|partes_autor_profissao   |partes_autor_cpf|partes_autor_endereco                                                     |partes_reu_nome      |partes_reu_nacionalidade|partes_reu_estado_civil|partes_reu_profissao |partes_reu_cpf_cnpj|partes_reu_endereco                                                    |descricao_causa_fatos                                                                                                                                                                                                                                                                                                                                                                                                                                     |descricao_causa_fundamento_legal    |descricao_causa_pedido                                                                                                                                                 |cpfCnpj_encrypted                                                                                   |partes_autor_cpf_encrypted                                                                          |partes_reu_cpf_cnpj_encrypted                                                                                           |partes_autor_nome_encrypted                                                                                             |partes_reu_nome_encrypted                                                                                               |partes_autor_endereco_encrypted                                                                                                                                                         |partes_reu_endereco_encrypted                                                                                                                                                           |andamento_processual                                                                                                                                                                                                                                                                                                                          |documentos_anexos                                                                                                               |
# +------------------------------------+--------------------------+--------------------------+-------------------+--------------+--------------------------------+-------------------------+----------------+------------+-----------------------+--------------------------------+-------------------+--------+---+-----------+-----------------+-----------------+--------------------------+-------------------------+-------------------------+----------------+--------------------------------------------------------------------------+---------------------+------------------------+-----------------------+---------------------+-------------------+-----------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------+
# |cf3f8db5-959e-46bf-b095-bb37ea4d39e0|2024-09-22 13:49:11.958495|2024-09-22 13:49:11.958498|0.9005228891606816 |245.387.091-23|https://eproc5.tjsc.jus.br/eproc|6883301-53.2013.8.38.2319|EM RECURSO      |3           |Maria Cecília Marques  |VARA CRIMINAL - DA PAZ ALEGRE   |JUSTIÇA ESTADUAL   |TST     |DF |307420.34  |2024-02-08       |Bryan Silva      |Brasileira                |Casado(a)                |Sushiman                 |321.954.086-42  |Estrada de Moreira, 27\nMarmiteiros\n31809-200 Oliveira / MG              |Moraes               |Brasileira              |Viúvo(a)               |Carnavalesco         |708.251.436-08     |Parque Abreu, 74\nConjunto Califórnia Ii\n00067-181 Cavalcanti / AP    |Laudantium esse quaerat cupiditate eius minus. Neque et vel fugiat labore voluptas.\nNesciunt quidem cumque iusto. Eligendi nostrum tenetur totam eveniet soluta. Doloremque quisquam dolore itaque sunt.\nEum vero eum ab quod debitis laborum. In illum id. Animi tempora libero expedita maxime iste. Quae laborum ratione ducimus accusamus.\nIure officia veniam veritatis omnis. Cum neque labore autem quia esse.                                  |Art. 339 do Código Trabalhista      |Debitis tempora minima nihil itaque odio odit. Sed perspiciatis minima debitis doloribus fugiat nulla nostrum. Saepe officia blanditiis excepturi exercitationem saepe.|gAAAAABm8Cndug2lARDw_K6jpEngpsc93REg_9FbUsCSuwFPxBtcD_U9rQS9M3worGY4fYKWPA_434jAEQFFJfC_XRlPNjIK8Q==|gAAAAABm8Cndbw5nHplYrQOn_MCpanzjlkOjRd0DW_WA-G1MmVtW1UFi5VAkQrjBi_4Pxo1jL_OsP63lC_1FXWzIMy8XOiXXcQ==|gAAAAABm8CndQ21nw-pCTPo9SgJlz3z_WS82SGdXnVIspwtYUXcoaiS8KNq1q9wA9jCaE4YoYpOtktHDbyg3mTW42anJkRF_pw==                    |gAAAAABm8Cnd7S1YYJaVVZfQNBt8OqsboDszw2Aunxl21uqpSzYnzQ9dCNQeUclGDPQ2JexzA30lA89OaVYXO53wsgkQ5p6fgA==                    |gAAAAABm8CndYhVLfF_0FnLYYAlnshID8KWhbb3QnILTGXJIj51sp7wipF2exxHDCF1RHOBfuEpSbb91ZPBJlN9MWZR_rOGs-Q==                    |gAAAAABm8Cndl63lzQKWdmDqqR9-tnm1pduUFejYP9hKLD9oYXo8Q4a6ryV_YCpjgt4PKzMmscwRAyEQftlz7pBAT8HJU5rf5aRnt44xv_Ap7M5V1HRA8UvdmJtRgWogFie641iWuSI1Li6gLrfs0FPRJ3IuwA3EoQ==                    |gAAAAABm8CndW1C6tyfQH0ydVaDBj5iEhPaznuALohusgV0qP4g28ySfv2WId9Nm2a3injnc8hoX7UXSAgOxKBAIe44T8Y3NzwsIfJpW_qOhhlB1LfhH06KefeI-YvH20V1TliQre0WTmGN6-sMjDnosF0-bN2jyDRb99bO8LKDghY7yuIjeveM=|[{2021-11-15, Contestação apresentada}, {2021-04-24, Audiência designada}, {2021-04-25, Contestação apresentada}, {2024-06-13, Contestação apresentada}, {2022-02-01, Petição inicial protocolada}, {2021-06-02, Audiência designada}, {2022-05-27, Audiência designada}, {2021-06-17, Sentença proferida}, {2023-04-18, Audiência designada}]|[Certidão - asperiores.pdf, Comprovante - dolorum.pdf, Petição - similique.pdf, Comprovante - aut.pdf, Laudo - voluptatibus.pdf]|
# |aa1528d7-017a-47ef-9067-26479e4a5dfe|2024-09-22 13:49:11.95855 |2024-09-22 13:49:11.958552|0.23185362502087714|250.839.716-40|https://eproc1.tjsc.jus.br/eproc|9018204-49.2014.4.81.5656|JULGADO         |2           |Henry Gabriel Souza    |VARA CRIMINAL - MACHADO         |JUSTIÇA ESTADUAL   |TRF-1   |RS |163079.21  |2022-06-13       |Zoe Camargo      |Brasileira                |Viúvo(a)                 |Telegrafista             |493.756.801-93  |Parque de Vasconcelos, 93\nMaria Tereza\n94809258 Montenegro do Galho / MS|Cauã Câmara          |Brasileira              |Casado(a)              |Nutricionista        |862.341.905-70     |Aeroporto Otávio Melo, 167\nAparecida\n54780-214 Barros / SC           |Tempore nesciunt alias nam libero quidem est officiis. Quasi asperiores itaque.\nSimilique assumenda cupiditate sint deleniti. Sed magni optio nam culpa blanditiis nemo.\nOptio libero hic eos natus. Officia deleniti quisquam pariatur. Alias quibusdam corporis reprehenderit assumenda est rem voluptas.\nNesciunt aperiam officiis consectetur officia. Autem veniam itaque voluptates sapiente quo labore.                                         |Art. 473 do Código de Processo Penal|Ipsam facere odio enim fugit ab quaerat. Reprehenderit maxime incidunt itaque earum delectus aut.\nSint veritatis nesciunt. Tenetur maiores nemo.                      |gAAAAABm8Cnd4z_lBfnwikhquRGHZepGUJLCYEyT4F4yBchCxcjbtnWy9ivmqfF8g7DEpZnkEBrOAXFMd-ZnMhKkY71qgkSQQQ==|gAAAAABm8Cnd7ZJFTGVb9F5tbm1XfbYk8aW7jZWB0Ax9JsqCNViIlkCqF96SDCi8GcT5z-u0KixcOm6D-nmnmS0NQr8HVwwxfg==|gAAAAABm8Cndwvjl3TuWw61oTTmsqZA4LF9Ln8O6exMjf-1rGmtYEghV3wWUQdh6DPY7u70hPwgEwefZyd1z31qf3sbxBD-0EA==                    |gAAAAABm8CndHcjtG4sr2B3ojmUw-1oUsbEUArW7KGnPMNQgitnZHjUDrSdtYWEOYS0rNLHTLBASGBtzMe6z9lpSQZZwhP3Q5g==                    |gAAAAABm8Cnd8yY_SRtAqtk0s-aP6aGTHBZI1s0u8A01lB5vs0MHrFdv6t-6evVoz_gUwG-ElWKsA2G5sUg39NRNhuvnmHZVgw==                    |gAAAAABm8Cndbb89SgEhfhDxHWZKmIxU8kNO2Uqr5O-VhF3PAV0OhFE5oskiGt7VENcfavgHOynqnvlZbyTE2nOsBoL1hdlgOnR20OjV1iruCAtYKQYfzkJiZ6Vy6f91TfwvaAlc3OUINvrD_MgUHL78Ji9evpHZTJ3fDvVWA_vRc3jN8jnzxXs=|gAAAAABm8Cnd6vta1tP3PHUHkFgLAn2rChmWrnMTw_VnrEs6XjiziiwOZWYiU1-Wj7SCi4V4Iu4iAc8RuHoB1I-Tgeo9TvGCqr8Dn1NFzha6HrFA4OJgMfUdaQh8UGPhOm-xnn3gFxCc4rKusfSbUYwt2sJ_yl3jRA==                    |[{2021-04-08, Sentença proferida}, {2021-09-10, Petição inicial protocolada}, {2020-08-01, Petição inicial protocolada}, {2021-08-25, Contestação apresentada}, {2019-09-23, Contestação apresentada}]                                                                                                                                        |[Petição - doloremque.pdf, Comprovante - vel.pdf]                                                                               |
# |46cbeb46-1d85-40ac-9db3-8dd8d0e4ff92|2024-09-22 13:49:11.958598|2024-09-22 13:49:11.958599|0.7945109419019253 |290.471.856-76|https://eproc5.tjsc.jus.br/eproc|5549595-11.2011.5.60.1096|EM ANDAMENTO    |1           |André Melo             |VARA TRABALHISTA - SANTOS       |JUSTIÇA FEDERAL    |TRF-5   |SP |196506.2   |2024-08-15       |Catarina Azevedo |Brasileira                |Casado(a)                |Coveiro/Sepultador       |492.876.053-00  |Estação Diogo Farias, 60\nDelta\n72755-244 Mendes / PB                    |da Costa Mendes Ltda.|Brasileira              |Solteiro(a)            |Engenheiro de energia|12.360.947/0001-92 |Trecho Ana Vitória Silva, 43\nAlto Das Antenas\n71662-685 da Cunha / AM|Velit mollitia et. In delectus rem nostrum itaque reiciendis quo. Ad cum cupiditate rem nulla.\nQuia natus ducimus deserunt nobis doloribus. Illo excepturi tenetur provident illum veniam ea. Veritatis animi rerum quis aut beatae.\nFuga impedit dolorem temporibus. Quam dolores voluptas totam distinctio optio. Quia natus tempora magnam non.\nReiciendis officia non aspernatur inventore. Ipsam laborum incidunt provident sit sequi.            |Art. 142 do Código Trabalhista      |Dolorum architecto recusandae cumque sunt. Itaque itaque a pariatur sequi delectus neque adipisci.                                                                     |gAAAAABm8CndcUaGAcs9FUx7sk48qCb_ULGHLbk6LwRHJxcErSrSDYNuUeUfYjMn5dHAjqsYfbAMamvXp-vhTsRshc2kh5zL5w==|gAAAAABm8CndMl34UcWopmJnzeoU1CuKNFP1rHjG8XpkASq1sROu_EnUKgguLkgJ9ylCg1tnXl-hX118o53hp5kn15WF5UnKTQ==|gAAAAABm8CndpEA3faeMDy9sxyG4HjQACJOvfbbyMdTl-f07PSfQ94GE5Fp8qNtkxX8W9NPDoxkMA8vG4pIPFAOl7LJb7oFyvr9ny4VP7E2MrwItt-PFldk=|gAAAAABm8Cndn_rIeOjVPXaq5wBQXcQC_tTtt4scsEHjhPsTKQVfKjfYHyopRsvqvt3lkQ8sDRQMFjkDGRn7CqgIheV1Dnb55o6Vu6ndeNGhWVTJRztepmM=|gAAAAABm8CndJwQ-DrsmMOmu1LIRS5jvFmv6BhOSLhWo0p_A7vpQiaKGAG79XkKatAT7u5ofcxLkcPRAQyPle1IMvm13XMfgocChUaVflzpu1a8TOQi0ul0=|gAAAAABm8Cndv76xbwaUGVOVks8NcTeQZdQHPeFvgZuWA_diGTk16APfT4xaGdNZDni5lav1HjyZHy_VMzD4WsIodzUPq6qpuFoR8DJXnA03WWCYNFqgk8Psc7xrX2z44YzvlKd9QobdGY9ocu42x_BwbzSI4JAEcg==                    |gAAAAABm8CndW1kJDmzVc2SGPf4E3Vfnzde4fKdfmWN4hTHzJBdFoJJwmXQavff-Db8eSxE-arPW9A6EECK_Z-r5JbkCyTV_TtELHqv76PHdsHXnDxCgvjplEx5So11jcCVrwpQ9Jr_4DACrOMLwsiFB3lt4MJLS5KGCWm_WjKRI7cHZyzRdl7Q=|[{2021-06-21, Contestação apresentada}, {2021-03-27, Audiência designada}, {2022-12-03, Recurso interposto}, {2021-02-20, Recurso interposto}]                                                                                                                                                                                                |[Laudo - fugiat.pdf, Procuração - officia.pdf, Procuração - incidunt.pdf, Certidão - repellendus.pdf, Certidão - minima.pdf]    |
# |95cf0107-0290-41f2-87c5-29e7c37a21d5|2024-09-22 13:49:11.958639|2024-09-22 13:49:11.95864 |0.6532886571948696 |785.139.402-32|https://eproc4.tjsc.jus.br/eproc|0235063-71.2018.8.77.8131|JULGADO         |3           |Davi Miguel Albuquerque|JUIZADO ESPECIAL CÍVEL - MARTINS|JUSTIÇA DO TRABALHO|TRF-1   |RS |728168.76  |2024-05-16       |Ana Júlia Fonseca|Brasileira                |Solteiro(a)              |Tecnólogo em silvicultura|940.263.715-06  |Morro Emanuel Cavalcanti\nNova Esperança\n47460-317 Novaes da Praia / MT  |Carvalho S.A.        |Brasileira              |Casado(a)              |Corretor de seguros  |72.146.530/0001-53 |Largo Olívia Jesus\nSão Benedito\n78686-497 Azevedo / RN               |Corporis culpa molestiae dignissimos eius id maiores. Facilis corrupti nam quae eos iste. Iusto minus ipsa fuga iure quibusdam nostrum.\nLaborum ex at ullam debitis velit consequatur. Doloribus quia quae fugiat aliquid ducimus aliquid.\nTenetur quo quibusdam minima harum reprehenderit sapiente porro. Quo minus sunt quaerat repellendus aspernatur.                                                                                              |Art. 405 do Código Trabalhista      |Molestiae harum quis itaque esse doloremque labore cumque. Neque deleniti deserunt suscipit repudiandae ad. Sequi quisquam adipisci ea.                                |gAAAAABm8CndN-QUTOzh2QIq_IScA__Kb4NW0D6SXiwmU6fT-CkkZni3u5uK7M-0LNKJ1lSuDfAx8AXmSwL1PB5iM8greG9HYQ==|gAAAAABm8CndlaVrihp0O-G0fTHHLHViEEAjMnEJ0Am_5ut3R_UsxiyTExYc-tYehfFYFJ_dsZpfJPurgqGZTO8JjnV0tghzAQ==|gAAAAABm8Cnd5JBbORnNsJHQRVSQbnMmTQ8DpNyYZ-yCx_QJycnUSun63LGLahmyIVx3qelD1iEaQyc8xQ8LzG4VfYeWOhtXaNAbkTl7uMS1bCzxH3iU6vc=|gAAAAABm8CndeS9z7RFHGNrnI2Q4ZLklVSU5yglqVQakb8_iDdFAjVEoo_sTl1pqrK__1i14P3O8-4uskMtTKHMPL-ottvhLVMDqwzMDg8GyKEa-xglyIDQ=|gAAAAABm8CndsrDOBC6wBi3UpOSVa8_sOHzv9nPCZUGNRQbj-hA3_-slepFiA1eXEks4zfmgdU5K69qWK0hIFCTviKwBX6LSvA==                    |gAAAAABm8CndWPz2jCgkfsdxbbXtgVj29b8u099qvn-um0uw4vMipFopMXa_DSuUnLq2y7SDRhzIWLAMlO2lhbzMzjl9185EvWNuoqTM9SHE4X3Z-eOctkk-lEPd083I_u-Wcqi3AanQRRG5vbZeoJ0QtOgacOmdr-aI7pYZXcAb6sSV81DYm58=|gAAAAABm8Cndl9CMGzUcBdCyt0wsjVXRK_Ono0dhaRPhPhVdyBLPSmej4tozHrARP9q8rdw9GpsiKVKVddmP4imyQlapsT7R2rjOQBiB2dF_EE2BeZrUHClYb2p8F2vfFtVnG79MYt7Yh8aYj-q5iF6JiJ6k1nE4TQ==                    |[{2020-10-18, Petição inicial protocolada}, {2023-05-06, Recurso interposto}, {2021-02-07, Audiência designada}]                                                                                                                                                                                                                              |[Petição - consectetur.pdf, Procuração - inventore.pdf, Procuração - hic.pdf]                                                   |
# |039e489f-7d3e-4f6c-81c2-acb9da36eaab|2024-09-22 13:49:11.958699|2024-09-22 13:49:11.9587  |0.1632492904625817 |695.217.304-80|https://eproc3.tjsc.jus.br/eproc|7096671-99.2022.3.79.4843|JULGADO         |1           |Leandro Abreu          |VARA DE FAMÍLIA - DA PAZ        |JUSTIÇA DO TRABALHO|TRF-5   |PR |884410.63  |2024-06-19       |Joaquim Alves    |Brasileira                |Divorciado(a)            |Timoneiro                |024.871.659-01  |Vereda Barbosa, 96\nVila Copasa\n65424-768 Albuquerque / AL               |Luiz Felipe Melo     |Brasileira              |Viúvo(a)               |Astrônomo            |321.985.740-04     |Passarela de Costa, 63\nVila Antena\n05802177 Rodrigues do Oeste / GO  |Animi expedita provident deserunt fugit. Similique impedit dolorem consequuntur illo vel culpa.\nDolores deleniti amet sit voluptatum repellendus sunt odio. Et quo distinctio. Dolore vero molestiae nesciunt voluptas. Aperiam eveniet aperiam iusto esse nostrum sint cum.\nVelit dolorum quidem eius accusamus dolorem facere. Sit eaque sint consequatur.\nQuae nostrum dicta impedit distinctio autem perferendis velit. Ad numquam voluptatem quia.|Art. 656 do Código Trabalhista      |Ab reprehenderit reiciendis fuga nostrum deserunt. Consectetur possimus omnis quidem.                                                                                  |gAAAAABm8CndPXBR-zJqT1aj4jMUJoDeMyadbVXc6dFckTV66PVeTRwwozFmF-N8XS5TvynsfUGh6BNq3uJ4LCPjPwdfNOM9NA==|gAAAAABm8CndQq0AfXKV1wOQe3dT3MjG7mBm7nwfE5qjonQEj7OZzRMUeVsMxLjZfx6i2sHb9c8sySsrQ5a-qhvRdEWT8y5W7g==|gAAAAABm8CndmwxOOL3c6VErZbGtBCd5q1U-6u9PNjDUxu2zpYMFoyV3_ihLcP7Ctm73WE7OxeEYatLws2u5yCJlHlLcD1HgiA==                    |gAAAAABm8Cnd3zDctTIWJHOAY_nPYbzBPYO5CC342CdtL97lnL4p9X6ZknYaMpX0WVFFSwGuaBVVrq-2OoNI0eW2akwPsF1_YQ==                    |gAAAAABm8CndqxFzb79oWRj4aOQ3mCL7dOP6O1PtaCY5RANxb-_1ymcgndUDR9R4AWxKYs4Zo39Yh-_XJOKVzQL9IDU9Khgv_4HukWtIcYXZAzbIkdTj7ms=|gAAAAABm8CndHTAJprNq79B0-vk0Vb5xDPwUZUkVRwamR1MNYtcMj7o6t901AkSaJ-RiBI3qj2g03ZSLXmjlLYO66KS2Pni6RnNnFrhbUhPNty1dgRucVg0sL8wWISLNQJIGKQRZZtXd7JnOc0-uU6UW8JU63Oju0Q==                    |gAAAAABm8CndtpgGbT5-4el_WwzS2mknCnY_HsStT4fcxeqNGmUkuuZZUw22BtTTBOS8E32xUstVNdBtnwTNGxoZEQUma7al1wSjcUR8yI544KVfLZeNP0Dpjj2l5AJoY20rf9X6lTzNoe-bbd1qmLPmVSTXmIc1h-LnxGn5MfIstluwSU_-l3k=|[{2022-04-27, Contestação apresentada}, {2024-07-04, Audiência designada}, {2019-12-22, Audiência designada}, {2019-10-23, Citação realizada}, {2022-04-05, Contestação apresentada}, {2022-08-12, Citação realizada}, {2023-08-28, Citação realizada}, {2024-03-15, Citação realizada}, {2021-02-19, Audiência designada}]                   |[Petição - laborum.pdf, Petição - cum.pdf, Comprovante - commodi.pdf, Certidão - ratione.pdf]                                   |
# +------------------------------------+--------------------------+--------------------------+-------------------+--------------+--------------------------------+-------------------------+----------------+------------+-----------------------+--------------------------------+-------------------+--------+---+-----------+-----------------+-----------------+--------------------------+-------------------------+-------------------------+----------------+--------------------------------------------------------------------------+---------------------+------------------------+-----------------------+---------------------+-------------------+-----------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------+
# only showing top 5 rows
#
#
# Schema dos dados processados:
# root
#  |-- id: string (nullable = true)
#  |-- data: timestamp (nullable = true)
#  |-- detitime: timestamp (nullable = true)
#  |-- tempo_da_ingestao: double (nullable = true)
#  |-- cpfCnpj: string (nullable = true)
#  |-- urlProcesso: string (nullable = true)
#  |-- numeroProcessoUnico: string (nullable = true)
#  |-- statusObservacao: string (nullable = true)
#  |-- grauProcesso: string (nullable = true)
#  |-- juiz: string (nullable = true)
#  |-- area: string (nullable = true)
#  |-- segmento: string (nullable = true)
#  |-- tribunal: string (nullable = true)
#  |-- uf: string (nullable = true)
#  |-- valor_causa: double (nullable = true)
#  |-- data_distribuicao: string (nullable = true)
#  |-- partes_autor_nome: string (nullable = true)
#  |-- partes_autor_nacionalidade: string (nullable = true)
#  |-- partes_autor_estado_civil: string (nullable = true)
#  |-- partes_autor_profissao: string (nullable = true)
#  |-- partes_autor_cpf: string (nullable = true)
#  |-- partes_autor_endereco: string (nullable = true)
#  |-- partes_reu_nome: string (nullable = true)
#  |-- partes_reu_nacionalidade: string (nullable = true)
#  |-- partes_reu_estado_civil: string (nullable = true)
#  |-- partes_reu_profissao: string (nullable = true)
#  |-- partes_reu_cpf_cnpj: string (nullable = true)
#  |-- partes_reu_endereco: string (nullable = true)
#  |-- descricao_causa_fatos: string (nullable = true)
#  |-- descricao_causa_fundamento_legal: string (nullable = true)
#  |-- descricao_causa_pedido: string (nullable = true)
#  |-- cpfCnpj_encrypted: string (nullable = true)
#  |-- partes_autor_cpf_encrypted: string (nullable = true)
#  |-- partes_reu_cpf_cnpj_encrypted: string (nullable = true)
#  |-- partes_autor_nome_encrypted: string (nullable = true)
#  |-- partes_reu_nome_encrypted: string (nullable = true)
#  |-- partes_autor_endereco_encrypted: string (nullable = true)
#  |-- partes_reu_endereco_encrypted: string (nullable = true)
#  |-- andamento_processual: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- data: string (nullable = true)
#  |    |    |-- descricao: string (nullable = true)
#  |-- documentos_anexos: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#
#
# Total de registros processados: 10000
# Total de colunas: 40
# Processando arquivo: /content/data_lake/raw_data/parquet/processo_juridico_2.parquet
# Iniciando processamento de 10000 registros.
# JSON expandido com sucesso.
# Campos relevantes extraídos.
# Campos sensíveis criptografados.
# Processamento concluído. Total de colunas: 40
# Dados processados salvos em /content/data_lake/processed_data/processo_juridico_2.parquet
#
# Amostra dos dados processados:
# +------------------------------------+--------------------------+--------------------------+-------------------+--------------+--------------------------------+-------------------------+----------------+------------+--------------------+--------------------------------------+-------------------+--------+---+-----------+-----------------+--------------------------+--------------------------+-------------------------+----------------------------------+----------------+--------------------------------------------------------------------------------+------------------+------------------------+-----------------------+--------------------+-------------------+-----------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------+
# |id                                  |data                      |detitime                  |tempo_da_ingestao  |cpfCnpj       |urlProcesso                     |numeroProcessoUnico      |statusObservacao|grauProcesso|juiz                |area                                  |segmento           |tribunal|uf |valor_causa|data_distribuicao|partes_autor_nome         |partes_autor_nacionalidade|partes_autor_estado_civil|partes_autor_profissao            |partes_autor_cpf|partes_autor_endereco                                                           |partes_reu_nome   |partes_reu_nacionalidade|partes_reu_estado_civil|partes_reu_profissao|partes_reu_cpf_cnpj|partes_reu_endereco                                                                |descricao_causa_fatos                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |descricao_causa_fundamento_legal    |descricao_causa_pedido                                                                                                                                                                                |cpfCnpj_encrypted                                                                                   |partes_autor_cpf_encrypted                                                                          |partes_reu_cpf_cnpj_encrypted                                                                                           |partes_autor_nome_encrypted                                                                                             |partes_reu_nome_encrypted                                                                                               |partes_autor_endereco_encrypted                                                                                                                                                         |partes_reu_endereco_encrypted                                                                                                                                                                               |andamento_processual                                                                                                                                                                                                                                                                                                    |documentos_anexos                                                                                               |
# +------------------------------------+--------------------------+--------------------------+-------------------+--------------+--------------------------------+-------------------------+----------------+------------+--------------------+--------------------------------------+-------------------+--------+---+-----------+-----------------+--------------------------+--------------------------+-------------------------+----------------------------------+----------------+--------------------------------------------------------------------------------+------------------+------------------------+-----------------------+--------------------+-------------------+-----------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------+
# |a1a967c5-f1e1-44a7-b060-f476d16da560|2024-09-22 13:49:40.14298 |2024-09-22 13:49:40.142983|0.32380294434416124|019.543.627-06|https://eproc4.tjsc.jus.br/eproc|0515611-81.2019.9.57.4762|JULGADO         |1           |Allana Silva        |VARA FEDERAL - OLIVEIRA GRANDE        |JUSTIÇA DO TRABALHO|TJ-RJ   |MG |419030.54  |2020-10-31       |Vinícius Câmara           |Brasileira                |Viúvo(a)                 |Oftalmologista                    |068.954.237-29  |Lago Montenegro, 501\nVila Satélite\n14274-843 Fernandes / PA                   |Isabelly Almeida  |Brasileira              |Divorciado(a)          |Engenheiro têxtil   |795.304.286-00     |Rua de Viana, 6\nDiamante\n37581768 Freitas do Campo / CE                          |Alias ex aspernatur mollitia quia amet deleniti mollitia. Nobis occaecati aut officia error dolores. Impedit molestiae nesciunt possimus porro.\nIure impedit facilis ut. Possimus et expedita similique cupiditate nulla quas aperiam. Nulla eum culpa illo.\nSoluta maiores ex. Autem perferendis mollitia.\nDoloribus pariatur dicta ipsum. Ad molestiae optio non illum ipsa corporis voluptates.\nSaepe et soluta id qui. Incidunt id assumenda quae. Cum sint eligendi libero commodi non deleniti.|Art. 712 do Código de Processo Penal|A possimus perferendis minima beatae animi expedita quaerat.\nExcepturi eveniet a quidem delectus odit. Amet laborum quas magni. Labore ex sapiente dolorum nihil libero.                             |gAAAAABm8CnqlE6V6YJlrXnwnBi7l476r8fOpd0g-kb4ilkwlAwiQkhV9HAVDzL66VJXhmFjJxSY5NgOHu6_84wygeYuwwvYfw==|gAAAAABm8CnqVpYxnjj9Tps7V-Hr3jW-frWqoDZ5sKWyQbScMQi90hl5atOwStTX2a_6TFY39eb4S2aM4UiEs5-Z-vP63WNqwg==|gAAAAABm8CnqLaYwCw1847Mu5Q5sKU85aC-LvIhGPPzhLNggOYoNhvS9jC5L62xlHWKY05Oa3CrGHR4_HuSSySjDiLH_ynUDIg==                    |gAAAAABm8CnqCx2ZmZJimqwm9KRonlj57VgnMi5YrwcA9KBLzefvNyB5LCbHuqWhF-PfU7o-HfbVRBcNke26eNYmJixfgv5f-6lWonkznQVpczrUFtD8Ygg=|gAAAAABm8Cnq4ACtMlxay022nBTbY2_AJ2DMpDLHY9k9yL1p1Wy8pqnwSvVyKG3LBMOKaGnvVJap8CkoED-5NWoK8JurGCHLr0s3RmGUXK00yEC8Mr5zv38=|gAAAAABm8Cnqs2CRIssrG5zmutDVi6_io2wgoBOnAPlqXu0OIW_ReeR0JjKm_MpFfEkpvDVRqYcczPgvasAEhIBPwnV17WqIA-Pql7vhtN7C4xW-CYSBvlR788K69slwcHJ-lXrrjhuFAjTvCaCIPHYnpo1v4onI5Q==                    |gAAAAABm8CnqN0Ruc5icBAlv0vi_1mp6KQ9Un9LO3KjHnEQrAzXpzTPkG77jB08wShxJgQJe93q0xT28jg9g6pTvEsI4pbQCE1csuk5YlwlvgqGybygjn6eb5a823UypXAYoGVAIbPJoChYRdeZ6ZQpPmnei-VEgpg==                                        |[{2019-12-25, Contestação apresentada}, {2021-11-13, Petição inicial protocolada}, {2021-03-30, Contestação apresentada}]                                                                                                                                                                                               |[Laudo - error.pdf, Petição - aspernatur.pdf, Comprovante - magnam.pdf]                                         |
# |6cb98827-6a96-46ef-98af-cddd6cb22da4|2024-09-22 13:49:40.143045|2024-09-22 13:49:40.143047|0.8200689964667652 |853.104.629-70|https://eproc4.tjsc.jus.br/eproc|0548641-09.2006.9.25.4765|ARQUIVADO       |1           |Emanuelly Silveira  |VARA TRABALHISTA - CAVALCANTE DO GALHO|JUSTIÇA FEDERAL    |TRF-2   |BA |63028.97   |2021-11-20       |Dra. Ana Sophia Jesus     |Brasileira                |Casado(a)                |Tecnólogo em negócios imobiliários|251.849.376-09  |Fazenda Alexandre Novaes, 60\nSão Benedito\n46826324 Araújo de Pastor / BA      |Pimenta Ramos - ME|Brasileira              |Divorciado(a)          |Telegrafista        |63.852.401/0001-90 |Quadra Monteiro, 54\nJardim América\n79775-273 Cavalcanti / PA                     |Sint blanditiis beatae quam consequatur quis. Provident sed rem fuga ipsam totam vel.\nMaiores adipisci quidem nihil debitis sequi quibusdam. Modi maiores eum inventore.\nTenetur ipsam ullam laudantium. Totam tempora ab.\nNulla magni eaque aliquam modi iste. Harum eligendi perferendis tempora.\nSapiente dicta at asperiores ab cum dignissimos vitae. Cumque natus voluptatum ducimus. Ducimus sunt ad doloribus quisquam qui voluptas.                                                         |Art. 564 do Código Trabalhista      |Eius dolores tenetur amet aspernatur. Nobis aliquam aspernatur corrupti.\nAssumenda pariatur et sed quaerat voluptatum vel. Ullam quam aliquam similique. A dolores quisquam aspernatur quia deleniti.|gAAAAABm8CnqaSTTiyH5TAyub2Tj_OAj8kK5-WNMenEqteFaQb0W5PmK2UtcyfS-xU_FIgFuyyaGozymbcXiULPn_rRiwsQsJA==|gAAAAABm8CnqRa4JOy_F6IRZJ9K1aSKwTD5N4ThVpnZJGSItxjtGIv135_rgigGlPLUyE6kz3S2Q2ZoAAtdS0u4Q8o2vq4BrmQ==|gAAAAABm8Cnqgn5XI28x-SuW5U8DPiWx0mvtF0WiOVJuZUrKAQGqNB91SVEJ2h9sD4J8-PMFw8amIF4a3bdJHvgpPhQ2ulke5lpDLTLQrDFjp8olGVG5gRY=|gAAAAABm8CnqxEvM8LXyiDtNdvkVJR3BXuID68a2gXQsePcQ3L5FpzmvN97Gk1jV40OwFgUj7NplgllG4Hn-MH-FRne1n6yM6hUEqkBUblCtEL1gOMvxx-k=|gAAAAABm8CnqmmDfeCNgB6RVlCaB04iwFReTPAiIs34X3VaCgxv6ZRPI1-1lJ2WqDLlgit_VACwQb4js2PBVWFiU4dE43fMqDH7N6Tkh-K6XZWl1gfocaOU=|gAAAAABm8CnqmRayApKCe_rFF8rNR7ZN5EADZ1e24yaPQhtJyFaYgN_6LCN57Hgmsb9UrSXsHsKsGUnnDpuSv_r8xPWfTvIKRZRFR1qmvmELpzrfeNyxKoyka5GEoUNLh17EByJh3HyYsY8bzcVrjyA42O9fhm49M7m2P4TGDDLwmrr6MQry444=|gAAAAABm8CnqoYIizkdBdvyV-EJl2qB-IgNWOdMnsjI14D-hY0OVUs4t5uzrJ-SBClpavwpcLMEZhromLkD_dF56gVBAfrjdBhjiQLTaHLNjr4SpoDvsDkFU_1pr_cGzaC_E-h_r9FFwLnSg9yUZyehgvgOJavGyuA==                                        |[{2024-02-11, Recurso interposto}, {2020-06-20, Audiência designada}, {2022-03-25, Recurso interposto}, {2022-09-19, Contestação apresentada}, {2021-10-05, Audiência designada}, {2021-11-22, Recurso interposto}, {2022-03-22, Audiência designada}, {2022-03-03, Citação realizada}, {2021-03-27, Citação realizada}]|[Certidão - provident.pdf, Comprovante - soluta.pdf, Procuração - nam.pdf]                                      |
# |fce1fd2e-c248-4669-88ac-00bc468dfa94|2024-09-22 13:49:40.143096|2024-09-22 13:49:40.143097|0.25743344592844786|085.439.162-24|https://eproc2.tjsc.jus.br/eproc|1309183-32.2011.8.75.8958|EM RECURSO      |2           |Ana Lívia Porto     |VARA TRABALHISTA - RIBEIRO            |JUSTIÇA DO TRABALHO|STJ     |SP |930205.51  |2022-02-20       |Sra. Ana Júlia Albuquerque|Brasileira                |Viúvo(a)                 |Agrônomo                          |802.634.571-17  |Trevo Moraes, 40\nGrotinha\n86314-680 Montenegro dos Dourados / DF              |Caroline Rezende  |Brasileira              |Divorciado(a)          |Numerólogo          |62.891.345/0001-30 |Recanto Moraes, 66\nJardim Atlântico\n53226110 Alves Verde / PR                    |Culpa totam odio vitae. Explicabo sed eveniet. Distinctio ut explicabo at explicabo necessitatibus impedit doloremque.\nReiciendis quia nesciunt molestias quis incidunt labore architecto. Ut repellat facilis assumenda nostrum eos.\nVoluptatem nisi dolores accusantium perferendis. Occaecati ipsa consectetur fugiat assumenda reiciendis quisquam. Deleniti soluta quaerat quos ea.\nMolestias ipsam vitae quidem mollitia. Laboriosam quisquam doloribus doloribus incidunt assumenda.           |Art. 912 do Código Civil            |Sit atque laudantium ea rem animi sunt nisi. Esse sint aspernatur odit nostrum illo voluptates. Maxime eum eum nesciunt consequatur perferendis. Pariatur nam ut illum vitae architecto.              |gAAAAABm8CnqsgUJ0OSVREFOpUVt-gyfKyW7Xz1-R8FhBkjoKtZSHGJRbQ7t-BjVxh4gjgIqhN3C5MIMI41MSPT_rN_zVdOv4Q==|gAAAAABm8Cnq51JuFs7dSFL6CEYtcIlRNCssHszW7fXJ2WbSri4MLHDR7YrCCd0YiBEg7IgU0EwxCXhPxcm-SWx6pmmbfTAA2g==|gAAAAABm8CnqZLpKPRUhWAn7NhG44A5YUjRmv_qP0RbUk748pH5gvDJ2BPHe0xydzQMHrnO5PQH_I1MyrPDHMZULkn_6Rmql-Ebj95FYW5LGyTEuDew8Upg=|gAAAAABm8Cnq4taAwNhf714Q4-x5zvAiSD8HaWcGmmU7EGneJMGXGHZiz_8wDif7pj8hvEsI6Q646smMzKBBS4k9BgIrGP92W8I9DtD5SQs3FhcV30GIkgM=|gAAAAABm8Cnqw7uJM389vY3BarE2HSAxmHKPxrx9rcwQ3R4H9Sj788Z3UVhI4guxFtYmcrrDfK9OWoHpCI5Mcj2gTv2yRFwl0MGQpy_RoMGu5mMdWhzDezk=|gAAAAABm8CnqerLFZHMLcbeVpz3SVFzmgt_8QA31UHpnjb6S1jYMcS-FxvN0Wgf1r-0l2ac2Gbao-cUPQXCgNhwRrhpdmXYd9h5VgLsoKCHGKXAPLWiw56E72YCbgmhz3PjL9iOYPATH60x1bkIrCqZQlmEf2RLGuFktKEAlhGXA2waRRPt-Fw0=|gAAAAABm8CnqPZ6q03nIuf4mxHq7eByg0lPtP7zE8RZxE_8rOnYswY5CVvLEpMNR0zZwmvPE7XVBI4x_f5lqPjHc7kPU84vUoH3aheVF-hfMb067lqdDhfgrcx_CY5e0aqCTJXmkkI8XDxM0W6lRiN4sOEm39WGl-g==                                        |[{2022-09-17, Citação realizada}, {2022-04-30, Contestação apresentada}, {2021-12-23, Audiência designada}, {2022-01-13, Recurso interposto}, {2020-08-04, Audiência designada}]                                                                                                                                        |[Procuração - iste.pdf, Laudo - eligendi.pdf, Laudo - enim.pdf, Petição - labore.pdf, Petição - praesentium.pdf]|
# |7e4480fc-57cc-404c-8f73-ce5c06b51a43|2024-09-22 13:49:40.143137|2024-09-22 13:49:40.143138|0.1360850004066764 |172.358.046-53|https://eproc3.tjsc.jus.br/eproc|9319040-36.2021.1.52.3368|EM RECURSO      |1           |Dr. Heitor Ribeiro  |VARA DE FAMÍLIA - MACEDO DA PRAIA     |JUSTIÇA ESTADUAL   |STF     |SC |961021.83  |2020-11-09       |Otávio Albuquerque        |Brasileira                |Divorciado(a)            |Seringueiro                       |517.309.426-52  |Loteamento Luísa Sousa, 708\nBaleia\n46355-861 Rios do Campo / RS               |Araújo            |Brasileira              |Divorciado(a)          |Psicólogo           |970.234.518-97     |Núcleo de Costela, 81\nBoa Viagem\n80173684 Moreira de da Cunha / PA               |Quod beatae dolores placeat magni voluptatum. Assumenda non repudiandae dolores explicabo tempore. Occaecati quam deserunt mollitia dolores. Quas delectus dolore.\nQuasi autem voluptatum voluptates dolorem deleniti beatae. Delectus praesentium eum in ab optio.\nQuos debitis voluptatum harum facere accusamus.\nRecusandae saepe illum. Magnam libero iusto vitae. Optio esse eveniet fuga nobis.\nVitae facere occaecati molestiae vel labore alias. Veniam quisquam vel ipsam nesciunt fugiat.  |Art. 809 do Código de Processo Civil|Ipsa aliquam cumque assumenda repellendus. Tempore voluptatum tempore inventore iure tenetur et. Pariatur at ullam sunt accusantium facilis culpa.                                                    |gAAAAABm8Cnq2vEP42zSQUwNmjHkn8Xy_krrnQUT-eYfg4m5yUXoeD3aY9vR3eEvh0z01UIKLL8YOT3wRqNTR8BN70C-8PkhHQ==|gAAAAABm8CnqYUo29wCnF9u0nOx4wB2iWDRLKqK3Z-n91LNh1JSVCyV9t8iO_4krR99NbNz0Q-GPowmXJkizFvTshrMKKaE89A==|gAAAAABm8CnqaufCaRNI0sVMIHlQ1BQ1TaiWwj_WhKFcfX5QKrOUS2h-vFny5e8UTEQQ2EGbKdM_Z4VENKl7wA5DKNBIDZhS2Q==                    |gAAAAABm8CnqBHMYcz9izP9XqQSUQUo_qK3cpbI_b0DZr40Cr0vRA4bJ4LSHBra2yeyqnQNwr7wn6dV1ipttkUlFdhUsMNxxfQW03CbF7MbeJXGhF5mF8qA=|gAAAAABm8CnqQY-9ZbppOKSL4tIKBGLg_gHC5I2clkECgykSX9FIoLIKRGoGEwqpzOEd3DiBSwJkwT98vxZ2VTmi_KgJELFJlw==                    |gAAAAABm8CnqBZhYSCqLAbqeHiVEMg7F5_kIEygwNMWUrKt0C4bIY8_VrC95Mn5-YuZapBoqxxEODCSVYaG1w_VdiKVgW5KuIZ8R6qkGuy4bULXTTHaW-gLwJzkhTed3O4EOzOfuUpnmVE5FU6DBamQEzW-nYKmAJwoDzdkKb-tDFO_Mu8IRHY0=|gAAAAABm8CnqOIfuHMvHim40UPwDQoOSsw-CDdc7oC4Ew0DJa-P4_LZZvsEHS0SDf0dKKcZXWlKRdEdU0gDNbCoV8lHQtC1Kvxdvu-spU1OUHxG86EsvBo_3vl8FHVWfjm5LYhIOJsQ3PIZIHg_GBq2c9T8lfVijav-_fz3E7t2MpkR6ClqmcJc=                    |[{2021-12-30, Recurso interposto}, {2023-05-24, Citação realizada}, {2023-09-29, Sentença proferida}]                                                                                                                                                                                                                   |[Comprovante - mollitia.pdf, Certidão - ipsa.pdf, Procuração - neque.pdf, Laudo - consequuntur.pdf]             |
# ...
# |fce1fd2e-c248-4669-88ac-00bc468dfa94|2024-09-22 13:49:40.143096|2024-09-22 13:49:40.143097|0.25743344592844786|085.439.162-24|https://eproc2.tjsc.jus.br/eproc|1309183-32.2011.8.75.8958|EM RECURSO      |2           |Ana Lívia Porto     |VARA TRABALHISTA - RIBEIRO            |JUSTIÇA DO TRABALHO|STJ     |SP |930205.51  |2022-02-20       |Sra. Ana Júlia Albuquerque|Brasileira                |Viúvo(a)                 |Agrônomo                          |802.634.571-17  |Trevo Moraes, 40\nGrotinha\n86314-680 Montenegro dos Dourados / DF              |Caroline Rezende  |Brasileira              |Divorciado(a)          |Numerólogo          |62.891.345/0001-30 |Recanto Moraes, 66\nJardim Atlântico\n53226110 Alves Verde / PR                    |Culpa totam odio vitae. Explicabo sed eveniet. Distinctio ut explicabo at explicabo necessitatibus impedit doloremque.\nReiciendis quia nesciunt molestias quis incidunt labore architecto. Ut repellat facilis assumenda nostrum eos.\nVoluptatem nisi dolores accusantium perferendis. Occaecati ipsa consectetur fugiat assumenda reiciendis quisquam. Deleniti soluta quaerat quos ea.\nMolestias ipsam vitae quidem mollitia. Laboriosam quisquam doloribus doloribus incidunt assumenda.           |Art. 912 do Código Civil            |Sit atque laudantium ea rem animi sunt nisi. Esse sint aspernatur odit nostrum illo voluptates. Maxime eum eum nesciunt consequatur perferendis. Pariatur nam ut illum vitae architecto.              |gAAAAABm8CoDfKZ902rYQzr8ohsQKfs_6aVAoltJhT1ECBIM6d-oxvd1aaYNr16Q9zUPzWx2Zez0T8kJ4J_RrWYgtScaRNtnRA==|gAAAAABm8CoD9zY7vhN5azmsudXHFove_zkjIuvCJSKhItlIoZGsj5mO1bNMZcKyuiqYs9laswODjhq_tTu2EGJ43ZVb4owVbQ==|gAAAAABm8CoD94bYYZdVkfQQM4DICtMkWRnOytU7w_i_ByT_Uc8uuP1ASST8QDJgELKdcA1TCaA42iq63dxzwekTQJYH_FdKhNnKXeai9bvhpNrMIfkDfHo=|gAAAAABm8CoDNTsrTU106Dt2YUuI77iL3dkXIBY7J6H-W8-oglC7pHblPeR9y6BDMwDmw42IxW73-MCov_-dQzMXE6kd2uNfTKKv2OcGHsKW7WkLp5aH5HE=|gAAAAABm8CoDn0BQmlMnnzGrY5TpKmNzE89H_5tubQD_rW3zr5tRcYdQU8EAHcn3LqxpSSdpjr9hT16r46gfLvPeYL8kPLGVkTsKUfyIQddiuT64qZD4BPk=|gAAAAABm8CoDNIh1hnhuHLQZfCdOwoDYcw2c9v7E2QhdJmLyI12N8pEQje8Rh9ZA6HAyRYAEfHMHL2E2snHvRDTLE9YtvSpyrCgIbqNcVn5wrWULWHNLmfh_VaJsnmJQYzIJYcU9fahxMObRgfL3jHk0tjYCPhe9l-iH77UYJin1wqFcPiSXWe4=|gAAAAABm8CoDCalsrPff-UYvKn42de5Fd-Gn5o_OKMUOb5MmNkT7OYtuhWLGbCgbEtlSrUrkLVhtKSyzhRfluioyaJs6I2FMKIVRJjdnP77iLwqlVJa7xm8CZNeqtJ6V78hDs2_ufTpuC_3XOIh3ITtGDKI7LUrl5A==                                        |[{2022-09-17, Citação realizada}, {2022-04-30, Contestação apresentada}, {2021-12-23, Audiência designada}, {2022-01-13, Recurso interposto}, {2020-08-04, Audiência designada}]                                                                                                                                        |[Procuração - iste.pdf, Laudo - eligendi.pdf, Laudo - enim.pdf, Petição - labore.pdf, Petição - praesentium.pdf]|
# |7e4480fc-57cc-404c-8f73-ce5c06b51a43|2024-09-22 13:49:40.143137|2024-09-22 13:49:40.143138|0.1360850004066764 |172.358.046-53|https://eproc3.tjsc.jus.br/eproc|9319040-36.2021.1.52.3368|EM RECURSO      |1           |Dr. Heitor Ribeiro  |VARA DE FAMÍLIA - MACEDO DA PRAIA     |JUSTIÇA ESTADUAL   |STF     |SC |961021.83  |2020-11-09       |Otávio Albuquerque        |Brasileira                |Divorciado(a)            |Seringueiro                       |517.309.426-52  |Loteamento Luísa Sousa, 708\nBaleia\n46355-861 Rios do Campo / RS               |Araújo            |Brasileira              |Divorciado(a)          |Psicólogo           |970.234.518-97     |Núcleo de Costela, 81\nBoa Viagem\n80173684 Moreira de da Cunha / PA               |Quod beatae dolores placeat magni voluptatum. Assumenda non repudiandae dolores explicabo tempore. Occaecati quam deserunt mollitia dolores. Quas delectus dolore.\nQuasi autem voluptatum voluptates dolorem deleniti beatae. Delectus praesentium eum in ab optio.\nQuos debitis voluptatum harum facere accusamus.\nRecusandae saepe illum. Magnam libero iusto vitae. Optio esse eveniet fuga nobis.\nVitae facere occaecati molestiae vel labore alias. Veniam quisquam vel ipsam nesciunt fugiat.  |Art. 809 do Código de Processo Civil|Ipsa aliquam cumque assumenda repellendus. Tempore voluptatum tempore inventore iure tenetur et. Pariatur at ullam sunt accusantium facilis culpa.                                                    |gAAAAABm8CoDLOpmRvGkU9jh7iYQHMSK4EB_QuaMWxdaxs7QUSvd5tUS3lzQczNzhM3EghEJA8CUXAgNN4WV-vAAbzmySPLnBQ==|gAAAAABm8CoDcmVD0djSHPd98r5cQpq1sfvveMDMhs_r3oQSAbI8sdQY5WvCsknB_hyeGiM6eiQejxeE3fnDT2qvAw8yqWB1xw==|gAAAAABm8CoDNAvTqHfG4ivgG_t8xhlOLgxQwYjBsMZ3EKyOcE1V1EB1DgpuE_SZ2V_kQNfLYCn6smyuI3OyIDqs7lJXuqMj2A==                    |gAAAAABm8CoDMTzWhczyTuPU-DPw7IoKxY92v7P02TIPh4WvDCngCm1K0NFCpL362oxKNDUcl6RAgSOBFwjptP_kW-2lTFepRIOghFzp5_uE5eI3bj9PAGU=|gAAAAABm8CoDzRf8tnI4QzH1ch61k8TdsuHLM9sLgx6HCV6C8La4JfHVW6angTor60cqdT4AiNWL9dOlGd0x8MzE_lAQ_vwj0A==                    |gAAAAABm8CoDBrAQZrzTXBT_WnJOZkFXpZTigTYtdozoIzB-Nfb_b1ek5cvifNkXWAknanPMFroeievgfbviZyvZiNwiX9dourGv7mKsNBohcSVsMewH0F0KmAlnni_iyyGMeB2fitnthTvuLQZ5DzuSmhiYLmhoebCjzQzLU-aN35JkxkpZEQs=|gAAAAABm8CoDgS1Yu7SKuayMiCblO6rauhkfBY7TJUwpRCSjhOouSd-udHQsrmoT12KDZQM5Z4jn4TeT8j6aho3xWexZKilSJOBazFZiFD9xLuZZtdAYLf82ksn-C5v6qP0G97s27uMbXPgX4W_FrBrM9RER176wwnfp9Rg9RvMw0pcPAeGNyuU=                    |[{2021-12-30, Recurso interposto}, {2023-05-24, Citação realizada}, {2023-09-29, Sentença proferida}]                                                                                                                                                                                                                   |[Comprovante - mollitia.pdf, Certidão - ipsa.pdf, Procuração - neque.pdf, Laudo - consequuntur.pdf]             |
# |9fc26e4e-40fd-42bd-a0ac-ae8f5a963b60|2024-09-22 13:49:40.143181|2024-09-22 13:49:40.143182|0.9380032154717507 |507.261.348-80|https://eproc1.tjsc.jus.br/eproc|5018992-35.2003.8.74.3726|EM ANDAMENTO    |3           |Valentina Nascimento|VARA TRABALHISTA - PORTO DO NORTE     |JUSTIÇA ESTADUAL   |STJ     |DF |964885.84  |2020-12-05       |Diego Cavalcanti          |Brasileira                |Divorciado(a)            |Juiz de direito                   |904.721.356-43  |Rua de Caldeira, 101\nVila Trinta E Um De Março\n05773-038 Fonseca do Norte / PR|Cavalcante        |Brasileira              |Viúvo(a)               |Armador             |83.214.906/0001-36 |Feira Aparecida, 928\nVila Santo Antônio Barroquinha\n38045-536 Viana do Galho / RS|Earum blanditiis suscipit dignissimos animi incidunt labore. Veritatis nam minima sunt voluptatem aut fugit. Nam aut odit iusto voluptas. Eum ab est cum praesentium repudiandae quisquam.\nDolore ea saepe inventore doloribus voluptatibus facilis. Ad excepturi odit dolorum laudantium eius voluptate. Laboriosam explicabo itaque. Cumque fugit illo veritatis tempora.\nDelectus ullam ducimus asperiores repellendus error atque. Nihil aut fugit occaecati quod.                                 |Art. 675 do Código Civil            |Ullam voluptatum omnis quisquam unde dolores vero. Iste consectetur repudiandae blanditiis voluptates. Aspernatur eveniet possimus quos.                                                              |gAAAAABm8CoDt8qsWXGaUMfh2NVi2iOp3VppT7HhSgo3ZAoPupwKsqnzSIthkanCvsoWohwmaPy0IMnMW9iKqN6gTQJQOHJB6Q==|gAAAAABm8CoDEd6DUBmY4mBVrvTZwa5NyP5l_oaGwHYnJ3X-eFJdIyj6z9v0B-zLdXHzZX5TgV-8bEEPnW0KqANkUhDraG630A==|gAAAAABm8CoDAxa6e1CRTouW6MECx-59f8TO21VTpoW8EVzy0kgrBvMPiZuirT5S1SfEkyyB_snxiJTKnCjelalcNkzd3jrqEUFSt-RWmdKdislbH12mCoQ=|gAAAAABm8CoDLdI0TFKGI3icfTosizZiiq8ZHGE7YxHu3UYyiNBUSpG23B0M6lEQ1S1yalOMN62AnnLNt-NAEultoHPFFTwrHHrSO-9xlcSxhud-5qduUR4=|gAAAAABm8CoDjC-QqiVLJf36Q_S-cg0RWJJhMEh4wPFC4MZb46me7gvkImS1BsPU9ltc1soqR-COKteWptRLttHb8cXKxCo3hw==                    |gAAAAABm8CoD7F5Kbf6ZbK7OnV9h8DIMgG771tBFgur40Og8c6UTbNbNVw30y9SwtDyNkbGb2IQvmxIxY-DyCF7MNoMmnYDHuOuVmjJgYOKo1TgH6z9YGqv10crnscHz5WdAOOvAw5dTA_v9Twb4REqgEX9ud3Qjuc-5MX4oOvowW56uxsqN8KY=|gAAAAABm8CoDb__Yjm4stboKUE5MWnsgh0uv5wymNUMbFUJkwX4Q5jW3HdG7veoViacmoi242ymM2ztjMZaDUc4AtZSlhAZapJmEO9J1FLWmilqJiIBCbEz3YvBePnjizYAKphJlwLR2Ppzdl5jHnlQ4-pJ0cV1Ft5t1zYNziUCwXUMTa26mvStta3CRt-JjGo_WJektUUEK|[{2021-03-09, Citação realizada}, {2022-05-04, Recurso interposto}, {2024-04-20, Citação realizada}, {2021-07-04, Citação realizada}, {2020-02-01, Audiência designada}, {2021-05-04, Recurso interposto}, {2022-03-11, Petição inicial protocolada}, {2024-07-16, Sentença proferida}]                                 |[Certidão - natus.pdf, Laudo - aspernatur.pdf, Laudo - voluptas.pdf, Comprovante - explicabo.pdf]               |
# +------------------------------------+--------------------------+--------------------------+-------------------+--------------+--------------------------------+-------------------------+----------------+------------+--------------------+--------------------------------------+-------------------+--------+---+-----------+-----------------+--------------------------+--------------------------+-------------------------+----------------------------------+----------------+--------------------------------------------------------------------------------+------------------+------------------------+-----------------------+--------------------+-------------------+-----------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------+
# only showing top 5 rows
#
#
# Schema dos dados processados:
# root
#  |-- id: string (nullable = true)
#  |-- data: timestamp (nullable = true)
#  |-- detitime: timestamp (nullable = true)
#  |-- tempo_da_ingestao: double (nullable = true)
#  |-- cpfCnpj: string (nullable = true)
#  |-- urlProcesso: string (nullable = true)
#  |-- numeroProcessoUnico: string (nullable = true)
#  |-- statusObservacao: string (nullable = true)
#  |-- grauProcesso: string (nullable = true)
#  |-- juiz: string (nullable = true)
#  |-- area: string (nullable = true)
#  |-- segmento: string (nullable = true)
#  |-- tribunal: string (nullable = true)
#  |-- uf: string (nullable = true)
#  |-- valor_causa: double (nullable = true)
#  |-- data_distribuicao: string (nullable = true)
#  |-- partes_autor_nome: string (nullable = true)
#  |-- partes_autor_nacionalidade: string (nullable = true)
#  |-- partes_autor_estado_civil: string (nullable = true)
#  |-- partes_autor_profissao: string (nullable = true)
#  |-- partes_autor_cpf: string (nullable = true)
#  |-- partes_autor_endereco: string (nullable = true)
#  |-- partes_reu_nome: string (nullable = true)
#  |-- partes_reu_nacionalidade: string (nullable = true)
#  |-- partes_reu_estado_civil: string (nullable = true)
#  |-- partes_reu_profissao: string (nullable = true)
#  |-- partes_reu_cpf_cnpj: string (nullable = true)
#  |-- partes_reu_endereco: string (nullable = true)
#  |-- descricao_causa_fatos: string (nullable = true)
#  |-- descricao_causa_fundamento_legal: string (nullable = true)
#  |-- descricao_causa_pedido: string (nullable = true)
#  |-- cpfCnpj_encrypted: string (nullable = true)
#  |-- partes_autor_cpf_encrypted: string (nullable = true)
#  |-- partes_reu_cpf_cnpj_encrypted: string (nullable = true)
#  |-- partes_autor_nome_encrypted: string (nullable = true)
#  |-- partes_reu_nome_encrypted: string (nullable = true)
#  |-- partes_autor_endereco_encrypted: string (nullable = true)
#  |-- partes_reu_endereco_encrypted: string (nullable = true)
#  |-- andamento_processual: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- data: string (nullable = true)
#  |    |    |-- descricao: string (nullable = true)
#  |-- documentos_anexos: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#
#
# Total de registros processados: 5120
# Total de colunas: 40
# Sessão do Spark encerrada.

# %% [markdown]
# ## 6. Conclusão
#
# O propósito deste projeto foi abordar e resolver os desafios apresentados no contexto do problema, atuando como um engenheiro de dados para implementar uma solução eficiente e escalável. Os principais problemas identificados e solucionados incluem:
#
# - **Inserção Automatizada de Dados**: Desenvolver um processo de ingestão que gera dados sintéticos (representa um crawler web ou API) de processos judiciais, eliminando a necessidade de entrada manual de dados e reduzindo significativamente os erros operacionais.
#
# - **Processamento e Transformação dos Dados**: Implementar um pipeline de processamento que extrai, transforma e carrega (ETL) os dados, estruturando-os de forma adequada para análises e relatórios. Isso inclui a expansão de dados JSON e a normalização de campos relevantes.
#
# - **Criptografia de Dados Sensíveis**: Para garantir a conformidade com a LGPD e proteger a privacidade dos indivíduos, aplicamos criptografia nos campos que contêm informações pessoais, como CPF/CNPJ, nomes e endereços (colunas com dados normais e colunas com encrypt). Isso assegura que dados confidenciais sejam armazenados e manipulados de forma segura.
#
# Ao abordar esses pontos, é logrado:
#
# - **Reduzir Erros Operacionais**: A automação dos processos minimiza a possibilidade de erros humanos, aumentando a precisão dos dados.
#
# - **Aumentar a Eficiência Operacional**: Libera-se recursos humanos para atividades mais estratégicas ao automatizar tarefas repetitivas.
#
# - **Melhorar a Disponibilidade e Tempestividade dos Dados**: Dados atualizados em tempo real estão disponíveis para análises e tomadas de decisão.
#
# - **Garantir a Centralidade e Unicidade dos Dados**: Todos os dados são armazenados em um data lake unificado, facilitando o acesso e a gestão das informações.
#
# - **Assegurar a Conformidade com Regulamentações**: Implementado medidas de segurança da informação e aderência à LGPD, protegendo a organização de riscos legais.
#
# Este projeto estabelece uma base sólida para futuras expansões e melhorias, tais como:
#
# - **Integração com Ferramentas de BI**: Os dados processados podem ser facilmente conectados ao Power BI ou outras ferramentas de análise para gerar insights valiosos.
#
# - **Criação de Alertas e Notificações**: Possibilidade de implementar triggers que alertem sobre prazos importantes ou mudanças nos processos.
#
# - **Aplicação de Inteligência Artificial**: Utilizar técnicas de machine learning para prever resultados de processos ou identificar cenários críticos antecipadamente.
#
# Em suma, o trabalho realizado resolve os problemas centrais do desafio proposto, alinhando-se aos objetivos de negócio e preparando o terreno para inovações futuras na gestão de dados judiciais.
#
# ---
#
# **Nota Final**: Este projeto demonstra a capacidade de identificar desafios operacionais e técnicos, propor soluções eficientes e implementá-las de forma a agregar valor ao negócio.
